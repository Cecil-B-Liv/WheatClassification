# %% [markdown]
# # **Importing Library**

# %% [markdown]
# ## Pip install thing (just to shorten the installation log)

# %%
# !pip install --user tensorflow==2.17
# !pip install --user matplotlib
# !pip install --user tensorflow-hub
# !pip install --user scikit-learn
# !pip install --user numpy==1.26.4 
# !pip install --user seaborn
# Out:
# Collecting tensorflow==2.17
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow==2.17) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-intel==2.17.0->tensorflow==2.17)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.4.0)
# Requirement already satisfied: packaging in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (4.25.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (79.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.71.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.0->tensorflow==2.17)
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (3.9.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\juras\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.45.1)
# Requirement already satisfied: rich in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (14.0.0)
# Requirement already satisfied: namex in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.0.8)
# Requirement already satisfied: optree in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17) (0.1.2)
# Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Using cached tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml_dtypes 0.5.1
#
#     Uninstalling ml_dtypes-0.5.1:
#
#       Successfully uninstalled ml_dtypes-0.5.1
#
#   Attempting uninstall: tensorboard
#
#     Found existing installation: tensorboard 2.19.0
#
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#     Uninstalling tensorboard-2.19.0:
#    ------------- -------------------------- 1/3 [tensorboard]
#       Successfully uninstalled tensorboard-2.19.0
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#   Attempting uninstall: tensorflow
#    ------------- -------------------------- 1/3 [tensorboard]
#     Found existing installation: tensorflow 2.19.0
#    ------------- -------------------------- 1/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#     Uninstalling tensorflow-2.19.0:
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#       Successfully uninstalled tensorflow-2.19.0
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    ---------------------------------------- 3/3 [tensorflow]
#
# Successfully installed ml-dtypes-0.4.1 tensorboard-2.17.1 tensorflow-2.17.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\juras\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.0 which is incompatible.
# Requirement already satisfied: matplotlib in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\juras\appdata\roaming\python\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: tensorflow-hub in c:\users\juras\appdata\roaming\python\python312\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\juras\appdata\roaming\python\python312\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-hub) (4.25.7)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\juras\appdata\roaming\python\python312\site-packages (from tensorflow-hub) (2.19.0)
# Collecting tensorflow<2.20,>=2.19 (from tf-keras>=2.14.1->tensorflow-hub)
#   Using cached tensorflow-2.19.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (79.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.13.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub)
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.45.1)
# Requirement already satisfied: rich in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (14.0.0)
# Requirement already satisfied: namex in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.0.8)
# Requirement already satisfied: optree in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# Using cached tensorflow-2.19.0-cp312-cp312-win_amd64.whl (376.0 MB)
# Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard, tensorflow
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml-dtypes 0.4.1
#
#     Uninstalling ml-dtypes-0.4.1:
#
#       Successfully uninstalled ml-dtypes-0.4.1
#
#   Attempting uninstall: tensorboard
#
#     Found existing installation: tensorboard 2.17.1
#
#    ------------- -------------------------- 1/3 [tensorboard]
#     Uninstalling tensorboard-2.17.1:
#    ------------- -------------------------- 1/3 [tensorboard]
#       Successfully uninstalled tensorboard-2.17.1
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#   Attempting uninstall: tensorflow
#    ------------- -------------------------- 1/3 [tensorboard]
#     Found existing installation: tensorflow 2.17.0
#    ------------- -------------------------- 1/3 [tensorboard]
#     Uninstalling tensorflow-2.17.0:
#    ------------- -------------------------- 1/3 [tensorboard]
#       Successfully uninstalled tensorflow-2.17.0
#    ------------- -------------------------- 1/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    ---------------------------------------- 3/3 [tensorflow]
#
# Successfully installed ml-dtypes-0.5.1 tensorboard-2.19.0 tensorflow-2.19.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\juras\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe and toco.exe are installed in 'C:\Users\juras\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.17.0 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.19.0 which is incompatible.
# Requirement already satisfied: scikit-learn in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\juras\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: numpy==1.26.4 in c:\users\juras\appdata\roaming\python\python312\site-packages (1.26.4)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: seaborn in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\juras\appdata\roaming\python\python312\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\juras\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\juras\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %% [markdown]
# ## Importing Library

# %% [markdown]
# ### Run this if you're on google colab

# %%
# import tensorflow as tf
# import tensorflow_hub as hub
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# import numpy as np
# import pandas as pd
# import os
# import glob
# import cv2
# import zipfile
# import shutil
# import random
# from pathlib import Path
# from PIL import Image
# import hashlib
#from tensorflow.keras import layers, models
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential  # Sequential API for building models layer by layer
# from tensorflow.keras.utils import to_categorical
#from tensorflow.keras.applications import MobileNetV2

# from google.colab import drive

# import warnings
# warnings.filterwarnings('ignore')

# print("TF version:", tf.__version__)
# print("Hub version:", hub.__version__)
# print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# # Check for GPU availability in TensorFlow
# device = "GPU" if len(tf.config.list_physical_devices('GPU')) > 0 else "CPU"
# print("The device is:", device)

# # rm -rf '/content/__MACOSX'
# # use this one when you need to remove folder and not getting must be empty error

# %% [markdown]
# ### Run this if you're on Jupyter Lab

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import os
import seaborn as sns
import glob
import cv2
import zipfile
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential  # Sequential API for building models layer by layer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
import shutil
from PIL import Image
import hashlib
import random
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Check for GPU availability in TensorFlow
device = "GPU" if len(tf.config.list_physical_devices('GPU')) > 0 else "CPU"
print("The device is:", device)

# rm -rf '/content/__MACOSX'
# use this one when you need to remove folder and not getting must be empty error
# Out:
# WARNING:tensorflow:From C:\Users\juras\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TF version: 2.19.0
# Hub version: 0.16.1
# GPU is NOT AVAILABLE
# The device is: CPU

# %% [markdown]
# # **Extracting Data**

# %% [markdown]
# ## Loading and Unzipping Data From Drive

# %% [markdown]
# ### If using google colab

# %%
# # Mount Google Drive
# drive.mount('/content/drive')

# # Define the extraction paths
# train_extract_path = '/content/drive/MyDrive/Colab Notebooks/train_images/train_images'
# test_extract_path = '/content/drive/MyDrive/Colab Notebooks/test_images/'

# # For train images: remove if exists, then extract
# if os.path.exists(train_extract_path):
#     print(f"Removing existing train images folder: {train_extract_path}")
#     shutil.rmtree(train_extract_path)
    
# # Create directory if it doesn't exist
# os.makedirs(train_extract_path, exist_ok=True)

# # Extract train images
# with zipfile.ZipFile('/content/drive/MyDrive/Dataset/train_images.zip', 'r') as train_zip_ref:
#     print("Extracting train images...")
#     train_zip_ref.extractall(train_extract_path)
#     print("Train images extracted successfully.")

# # For test images: remove if exists, then extract
# if os.path.exists(test_extract_path):
#     print(f"Removing existing test images folder: {test_extract_path}")
#     shutil.rmtree(test_extract_path)
    
# # Create directory if it doesn't exist
# os.makedirs(test_extract_path, exist_ok=True)

# # Extract test images
# with zipfile.ZipFile('/content/drive/MyDrive/Dataset/test_images.zip', 'r') as test_zip_ref:
#     print("Extracting test images...")
#     test_zip_ref.extractall(test_extract_path)
#     print("Test images extracted successfully.")

# print("All extraction complete!")

# %% [markdown]
# ### If using Jupyter

# %%
# Define the extraction paths
train_extract_path = 'dataset/train_images/'
test_extract_path = 'dataset/test_images/'

# For train images: remove if exists, then extract
if os.path.exists(train_extract_path):
    print(f"Removing existing train images folder: {train_extract_path}")
    shutil.rmtree(train_extract_path)
    
# Create directory if it doesn't exist
os.makedirs(train_extract_path, exist_ok=True)

# Extract train images
with zipfile.ZipFile('zip_data/train_images.zip', 'r') as train_zip_ref:
    print("Extracting train images...")
    train_zip_ref.extractall(train_extract_path)
    print("Train images extracted successfully.")

# For test images: remove if exists, then extract
if os.path.exists(test_extract_path):
    print(f"Removing existing test images folder: {test_extract_path}")
    shutil.rmtree(test_extract_path)
    
# Create directory if it doesn't exist
os.makedirs(test_extract_path, exist_ok=True)

# Extract test images
with zipfile.ZipFile('zip_data/test_images.zip', 'r') as test_zip_ref:
    print("Extracting test images...")
    test_zip_ref.extractall(test_extract_path)
    print("Test images extracted successfully.")

print("All extraction complete!")
# Out:
# Removing existing train images folder: dataset/train_images/
# Extracting train images...
# Train images extracted successfully.
# Removing existing test images folder: dataset/test_images/
# Extracting test images...
# Test images extracted successfully.
# All extraction complete!

# %% [markdown]
# ### Check Class Names

# %%
CLASS_NAMES = [os.path.basename(l) for l in glob.glob('dataset/train_images/train_images/*')
               if '.' not in l]
# CLASS_NAMES = [os.path.basename(l) for l in glob.glob('/content/drive/MyDrive/Colab Notebooks/train_images/train_images/*')
#                if '.' not in l]  ## if on google colab
print(CLASS_NAMES)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %% [markdown]
# ### Read The CSV File

# %%
# train_df = pd.read_csv('/content/drive/MyDrive/Dataset/meta_train.csv')
train_df = pd.read_csv('opencv/meta_train.csv')
train_df
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %% [markdown]
# ### Add path to the csv file

# %%
# train_df['path'] = '/content/drive/MyDrive/Colab Notebooks/train_images/' + train_df['label'] + "/" + train_df["image_id"]
train_df['path'] = 'dataset/train_images/train_images/' + train_df['label'] + "/" + train_df["image_id"]
train_df.head()
# Out:
#      image_id                  label variety  age  \
# 0  100330.jpg  bacterial_leaf_blight   ADT45   45
# 1  100365.jpg  bacterial_leaf_blight   ADT45   45
# 2  100382.jpg  bacterial_leaf_blight   ADT45   45
# 3  100632.jpg  bacterial_leaf_blight   ADT45   45
# 4  101918.jpg  bacterial_leaf_blight   ADT45   45
#
#                                                 path
# 0  dataset/train_images/train_images/bacterial_le...
# 1  dataset/train_images/train_images/bacterial_le...
# 2  dataset/train_images/train_images/bacterial_le...
# 3  dataset/train_images/train_images/bacterial_le...
# 4  dataset/train_images/train_images/bacterial_le...

# %% [markdown]
# ### Load some images for testing

# %%
# Select one image per label
unique_labels = train_df.groupby("label").first().reset_index()
images_per_row = 4  # Changed to 4 images per row
num_rows = (len(unique_labels) + images_per_row - 1) // images_per_row  # Calculate number of rows

# Create subplots with the calculated number of rows and columns
fig, axes = plt.subplots(num_rows, images_per_row, figsize=(16, num_rows * 3.5))  # Adjusted figure size
axes = axes.flatten()  # Flatten axes array for easier iteration

for idx, (_, row) in enumerate(unique_labels.iterrows()):  # Plot images
    img_path, label = row["path"], row["label"]
    if not os.path.exists(img_path):  # Check if the image exists
        print(f"Image not found: {img_path}")
        axes[idx].axis("off")
        continue
    img = cv2.imread(img_path)
    if img is None:
        print(f"Failed to load image: {img_path}")
        axes[idx].axis("off")
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img_shape = img.shape
    print(f"{label}: {img_shape}")
    axes[idx].imshow(img)
    axes[idx].set_title(f"{label}\n{img_shape}", fontsize=9)  # Smaller title font
    axes[idx].axis("off")

for idx in range(len(unique_labels), len(axes)):  # Turn off axis for any remaining unused subplots
    axes[idx].axis("off")

plt.tight_layout(pad=0.4, w_pad=0.2, h_pad=0.2)  # Even tighter spacing
plt.subplots_adjust(wspace=0.05, hspace=0.15)  # Further reduced space between subplots
plt.show()
# Out:
# bacterial_leaf_blight: (640, 480, 3)
# bacterial_leaf_streak: (640, 480, 3)
# bacterial_panicle_blight: (640, 480, 3)
# blast: (640, 480, 3)
# brown_spot: (640, 480, 3)
# dead_heart: (640, 480, 3)
# downy_mildew: (640, 480, 3)
# hispa: (640, 480, 3)
# normal: (640, 480, 3)
# tungro: (640, 480, 3)

# %% [markdown]
# # **Data Loading and Preprocessing**

# %% [markdown]
# ### Check duplicates in dataset

# %%
def calculate_hash(image_path):
    with Image.open(image_path) as img:
        return hashlib.md5(img.tobytes()).hexdigest()

def find_duplicates_in_dataset(root_folder):
    hashes = {}
    duplicates = []

    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(('.png', '.jpg')):
                path = os.path.join(subdir, file)
                try:
                    file_hash = calculate_hash(path)
                    if file_hash in hashes:
                        duplicates.append((path, hashes[file_hash]))
                    else:
                        hashes[file_hash] = path
                except Exception as e:
                    print(f"Error processing {file}: {e}")
    
    return duplicates
    
# Function to delete duplicate files, keeping only the first occurrence
def remove_duplicate_files(duplicates):
    removed_count = 0
    for duplicate_path, original_path in duplicates:
        try:
            # Check if file exists before attempting to remove
            if os.path.exists(duplicate_path):
                os.remove(duplicate_path)
                print(f"Removed: {duplicate_path}")
                removed_count += 1
            else:
                print(f"File not found: {duplicate_path}")
        except Exception as e:
            print(f"Error removing {duplicate_path}: {e}")
    
    return removed_count

duplicates = find_duplicates_in_dataset('dataset/train_images/train_images')
for dup1, dup2 in duplicates:
    print(f"Duplicate found:\n -> {dup1}\n -> {dup2}\n")
# Out:
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\100513.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\100169.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\103032.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\100133.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\104800.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\102353.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\105878.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\103344.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\106984.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\100998.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\107812.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\100635.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\108125.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\102038.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_leaf_blight\108353.jpg
#  -> dataset/train_images/train_images\bacterial_leaf_blight\101173.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\bacterial_panicle_blight\104803.jpg
#  -> dataset/train_images/train_images\bacterial_panicle_blight\104320.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\102705.jpg
#  -> dataset/train_images/train_images\blast\102334.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\105626.jpg
#  -> dataset/train_images/train_images\blast\104586.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\105840.jpg
#  -> dataset/train_images/train_images\blast\101343.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\105962.jpg
#  -> dataset/train_images/train_images\blast\101483.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\106520.jpg
#  -> dataset/train_images/train_images\blast\106102.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\107069.jpg
#  -> dataset/train_images/train_images\blast\100501.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\108455.jpg
#  -> dataset/train_images/train_images\blast\108403.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\108989.jpg
#  -> dataset/train_images/train_images\blast\100522.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\109346.jpg
#  -> dataset/train_images/train_images\blast\104021.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\blast\109773.jpg
#  -> dataset/train_images/train_images\blast\105038.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\102827.jpg
#  -> dataset/train_images/train_images\brown_spot\100939.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\104373.jpg
#  -> dataset/train_images/train_images\brown_spot\102063.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\104862.jpg
#  -> dataset/train_images/train_images\brown_spot\102938.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\105245.jpg
#  -> dataset/train_images/train_images\brown_spot\103128.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\105916.jpg
#  -> dataset/train_images/train_images\brown_spot\105649.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\106948.jpg
#  -> dataset/train_images/train_images\brown_spot\105169.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\107005.jpg
#  -> dataset/train_images/train_images\brown_spot\106596.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\107088.jpg
#  -> dataset/train_images/train_images\brown_spot\105194.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\108604.jpg
#  -> dataset/train_images/train_images\brown_spot\103415.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\109494.jpg
#  -> dataset/train_images/train_images\brown_spot\106860.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\109596.jpg
#  -> dataset/train_images/train_images\brown_spot\101456.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\brown_spot\110157.jpg
#  -> dataset/train_images/train_images\brown_spot\102859.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\103245.jpg
#  -> dataset/train_images/train_images\dead_heart\101021.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\103299.jpg
#  -> dataset/train_images/train_images\dead_heart\100206.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\103591.jpg
#  -> dataset/train_images/train_images\dead_heart\103195.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\104196.jpg
#  -> dataset/train_images/train_images\dead_heart\103215.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\106209.jpg
#  -> dataset/train_images/train_images\dead_heart\101578.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\106481.jpg
#  -> dataset/train_images/train_images\dead_heart\101868.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\106924.jpg
#  -> dataset/train_images/train_images\dead_heart\103329.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\107011.jpg
#  -> dataset/train_images/train_images\dead_heart\104957.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\107569.jpg
#  -> dataset/train_images/train_images\dead_heart\103001.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\108094.jpg
#  -> dataset/train_images/train_images\dead_heart\107526.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\109458.jpg
#  -> dataset/train_images/train_images\dead_heart\101222.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\110000.jpg
#  -> dataset/train_images/train_images\dead_heart\101868.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\dead_heart\110040.jpg
#  -> dataset/train_images/train_images\dead_heart\107311.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\downy_mildew\107847.jpg
#  -> dataset/train_images/train_images\downy_mildew\103260.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\downy_mildew\108591.jpg
#  -> dataset/train_images/train_images\downy_mildew\100017.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\hispa\101948.jpg
#  -> dataset/train_images/train_images\hispa\101512.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\hispa\106309.jpg
#  -> dataset/train_images/train_images\hispa\105621.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\hispa\107078.jpg
#  -> dataset/train_images/train_images\hispa\104143.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\hispa\108832.jpg
#  -> dataset/train_images/train_images\hispa\101788.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\hispa\109935.jpg
#  -> dataset/train_images/train_images\hispa\108645.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\100602.jpg
#  -> dataset/train_images/train_images\normal\100007.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\102440.jpg
#  -> dataset/train_images/train_images\normal\100285.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\104451.jpg
#  -> dataset/train_images/train_images\normal\100844.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\104484.jpg
#  -> dataset/train_images/train_images\normal\100737.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\106265.jpg
#  -> dataset/train_images/train_images\normal\100844.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107152.jpg
#  -> dataset/train_images/train_images\normal\106308.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107379.jpg
#  -> dataset/train_images/train_images\normal\101331.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107385.jpg
#  -> dataset/train_images/train_images\normal\102598.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107675.jpg
#  -> dataset/train_images/train_images\normal\105315.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107872.jpg
#  -> dataset/train_images/train_images\normal\103763.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\107897.jpg
#  -> dataset/train_images/train_images\normal\100344.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\108015.jpg
#  -> dataset/train_images/train_images\normal\104634.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\109156.jpg
#  -> dataset/train_images/train_images\normal\101562.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\109634.jpg
#  -> dataset/train_images/train_images\normal\102843.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\normal\109805.jpg
#  -> dataset/train_images/train_images\normal\106366.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\104027.jpg
#  -> dataset/train_images/train_images\tungro\100100.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\104901.jpg
#  -> dataset/train_images/train_images\tungro\100689.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\105747.jpg
#  -> dataset/train_images/train_images\tungro\103091.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\106461.jpg
#  -> dataset/train_images/train_images\tungro\101739.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\106650.jpg
#  -> dataset/train_images/train_images\tungro\105231.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\106818.jpg
#  -> dataset/train_images/train_images\tungro\104116.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\107269.jpg
#  -> dataset/train_images/train_images\tungro\101086.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images\tungro\107641.jpg
#  -> dataset/train_images/train_images\tungro\101445.jpg

# %% [markdown]
# Then we will remove these dulpicate ones from the dataframe

# %% [markdown]
# Then we need to remove it from the dataset as well.

# %%
# Remove the duplicate files from the filesystem
if duplicates:
    removed_count = remove_duplicate_files(duplicates)
    print(f"\n✅ Removed {removed_count} duplicate image files")
else:
    print("No duplicates found.")

# If you also need to update your dataframe after removing files
if 'train_df' in locals() or 'train_df' in globals():
    # Extract ONLY the duplicate paths (not the originals) to remove from dataframe
    paths_to_remove = [duplicate_path for duplicate_path, original_path in duplicates]
    
    # Normalize paths to ensure consistent comparison
    train_df['path'] = train_df['path'].apply(os.path.normpath)
    paths_to_remove = [os.path.normpath(path) for path in paths_to_remove]
    
    # Remove only the duplicate entries from dataframe
    original_length = len(train_df)
    train_df = train_df[~train_df['path'].isin(paths_to_remove)].reset_index(drop=True)
    removed_count = original_length - len(train_df)
    
    print(f"Removed {removed_count} duplicate image entries from dataframe")
# Out:
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\100513.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\103032.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\104800.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\105878.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\106984.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\107812.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\108125.jpg
# Removed: dataset/train_images/train_images\bacterial_leaf_blight\108353.jpg
# Removed: dataset/train_images/train_images\bacterial_panicle_blight\104803.jpg
# Removed: dataset/train_images/train_images\blast\102705.jpg
# Removed: dataset/train_images/train_images\blast\105626.jpg
# Removed: dataset/train_images/train_images\blast\105840.jpg
# Removed: dataset/train_images/train_images\blast\105962.jpg
# Removed: dataset/train_images/train_images\blast\106520.jpg
# Removed: dataset/train_images/train_images\blast\107069.jpg
# Removed: dataset/train_images/train_images\blast\108455.jpg
# Removed: dataset/train_images/train_images\blast\108989.jpg
# Removed: dataset/train_images/train_images\blast\109346.jpg
# Removed: dataset/train_images/train_images\blast\109773.jpg
# Removed: dataset/train_images/train_images\brown_spot\102827.jpg
# Removed: dataset/train_images/train_images\brown_spot\104373.jpg
# Removed: dataset/train_images/train_images\brown_spot\104862.jpg
# Removed: dataset/train_images/train_images\brown_spot\105245.jpg
# Removed: dataset/train_images/train_images\brown_spot\105916.jpg
# Removed: dataset/train_images/train_images\brown_spot\106948.jpg
# Removed: dataset/train_images/train_images\brown_spot\107005.jpg
# Removed: dataset/train_images/train_images\brown_spot\107088.jpg
# Removed: dataset/train_images/train_images\brown_spot\108604.jpg
# Removed: dataset/train_images/train_images\brown_spot\109494.jpg
# Removed: dataset/train_images/train_images\brown_spot\109596.jpg
# Removed: dataset/train_images/train_images\brown_spot\110157.jpg
# Removed: dataset/train_images/train_images\dead_heart\103245.jpg
# Removed: dataset/train_images/train_images\dead_heart\103299.jpg
# Removed: dataset/train_images/train_images\dead_heart\103591.jpg
# Removed: dataset/train_images/train_images\dead_heart\104196.jpg
# Removed: dataset/train_images/train_images\dead_heart\106209.jpg
# Removed: dataset/train_images/train_images\dead_heart\106481.jpg
# Removed: dataset/train_images/train_images\dead_heart\106924.jpg
# Removed: dataset/train_images/train_images\dead_heart\107011.jpg
# Removed: dataset/train_images/train_images\dead_heart\107569.jpg
# Removed: dataset/train_images/train_images\dead_heart\108094.jpg
# Removed: dataset/train_images/train_images\dead_heart\109458.jpg
# Removed: dataset/train_images/train_images\dead_heart\110000.jpg
# Removed: dataset/train_images/train_images\dead_heart\110040.jpg
# Removed: dataset/train_images/train_images\downy_mildew\107847.jpg
# Removed: dataset/train_images/train_images\downy_mildew\108591.jpg
# Removed: dataset/train_images/train_images\hispa\101948.jpg
# Removed: dataset/train_images/train_images\hispa\106309.jpg
# Removed: dataset/train_images/train_images\hispa\107078.jpg
# Removed: dataset/train_images/train_images\hispa\108832.jpg
# Removed: dataset/train_images/train_images\hispa\109935.jpg
# Removed: dataset/train_images/train_images\normal\100602.jpg
# Removed: dataset/train_images/train_images\normal\102440.jpg
# Removed: dataset/train_images/train_images\normal\104451.jpg
# Removed: dataset/train_images/train_images\normal\104484.jpg
# Removed: dataset/train_images/train_images\normal\106265.jpg
# Removed: dataset/train_images/train_images\normal\107152.jpg
# Removed: dataset/train_images/train_images\normal\107379.jpg
# Removed: dataset/train_images/train_images\normal\107385.jpg
# Removed: dataset/train_images/train_images\normal\107675.jpg
# Removed: dataset/train_images/train_images\normal\107872.jpg
# Removed: dataset/train_images/train_images\normal\107897.jpg
# Removed: dataset/train_images/train_images\normal\108015.jpg
# Removed: dataset/train_images/train_images\normal\109156.jpg
# Removed: dataset/train_images/train_images\normal\109634.jpg
# Removed: dataset/train_images/train_images\normal\109805.jpg
# Removed: dataset/train_images/train_images\tungro\104027.jpg
# Removed: dataset/train_images/train_images\tungro\104901.jpg
# Removed: dataset/train_images/train_images\tungro\105747.jpg
# Removed: dataset/train_images/train_images\tungro\106461.jpg
# Removed: dataset/train_images/train_images\tungro\106650.jpg
# Removed: dataset/train_images/train_images\tungro\106818.jpg
# Removed: dataset/train_images/train_images\tungro\107269.jpg
# Removed: dataset/train_images/train_images\tungro\107641.jpg
#
# ✅ Removed 74 duplicate image files
# Removed 74 duplicate image entries from dataframe

# %%
train_df
# Out:
#          image_id                  label variety  age  \
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10328  107607.jpg                 tungro   Zonal   55
# 10329  107811.jpg                 tungro   Zonal   55
# 10330  108547.jpg                 tungro   Zonal   55
# 10331  110245.jpg                 tungro   Zonal   55
# 10332  110381.jpg                 tungro   Zonal   55
#
#                                                     path
# 0      dataset\train_images\train_images\bacterial_le...
# 1      dataset\train_images\train_images\bacterial_le...
# 2      dataset\train_images\train_images\bacterial_le...
# 3      dataset\train_images\train_images\bacterial_le...
# 4      dataset\train_images\train_images\bacterial_le...
# ...                                                  ...
# 10328  dataset\train_images\train_images\tungro\10760...
# 10329  dataset\train_images\train_images\tungro\10781...
# 10330  dataset\train_images\train_images\tungro\10854...
# 10331  dataset\train_images\train_images\tungro\11024...
# 10332  dataset\train_images\train_images\tungro\11038...
#
# [10333 rows x 5 columns]

# %% [markdown]
# ### Data Distribution

# %%
# Visualize class distribution
plt.figure(figsize=(12, 6))
class_counts = train_df['label'].value_counts()
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class Distribution in Training Data')
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Print the exact counts
print("Class distribution:")
for label, count in class_counts.items():
    print(f"{label}: {count} samples ({count/len(train_df)*100:.2f}%)")
# Out:
# Class distribution:
# normal: 1749 samples (16.93%)
# blast: 1728 samples (16.72%)
# hispa: 1589 samples (15.38%)
# dead_heart: 1429 samples (13.83%)
# tungro: 1080 samples (10.45%)
# brown_spot: 953 samples (9.22%)
# downy_mildew: 618 samples (5.98%)
# bacterial_leaf_blight: 471 samples (4.56%)
# bacterial_leaf_streak: 380 samples (3.68%)
# bacterial_panicle_blight: 336 samples (3.25%)

# %% [markdown]
# In order to handle imbalance in dataset, I will perform data augmentation with class weighting, this way instead of physically duplicating images, we will apply data augmentation which create variety in the dataset and class weights will help making the model pay more attention to underrespresented class.

# %% [markdown]
# ### Data Normalization and Data Generator

# %%
BATCH_SIZE = 32 # 64
IMAGE_SHAPE = (224,244)
train_data_path = 'dataset/train_images/train_images/'

# For training data - with augmentation
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0/255.0,
    validation_split=0.2,  # We'll still use this to split the data
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2],
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# For validation data - only rescaling, but with the same validation split
valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0/255.0,
    validation_split=0.2  # Same split ratio to ensure consistent data division
)

# %% [markdown]
# With these parameters as data augmentation parameters, I split the dataset with the reatio of 0.8-0.2.

# %%
# For training data (with augmentation)
train_gen = train_datagen.flow_from_directory(
    train_data_path,
    subset="training",  # Use the training subset
    seed=42,
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    color_mode="rgb"
)
# Out:
# Found 8271 images belonging to 10 classes.

# %%
# For validation data (without augmentation)
valid_gen = valid_datagen.flow_from_directory(
    train_data_path,  # Note: using the SAME directory as training
    subset="validation",  # But using the validation subset
    seed=42,  # Use the same seed to ensure consistent splitting
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 2062 images belonging to 10 classes.

# %% [markdown]
# The total of both of these values are 10407 images in total.

# %% [markdown]
# ### Data Class Weighting

# %% [markdown]
# Calculating class weighting on the dataframe

# %%
def calculate_class_weights(class_counts):
    """
    Calculate class weights inversely proportional to class frequencies.
    Returns a dictionary with original class labels as keys.
    """
    total_samples = sum(class_counts)     # Get total number of samples across all classes
    num_classes = len(class_counts)
    class_weights = {}  # Compute class weights: inverse of frequency
                        # Use the original class labels as keys
    for class_name, count in class_counts.items():
        class_weights[class_name] = total_samples / (num_classes * count)
    
    # Print the weights for verification
    print("Class weights:")
    for class_name, weight in class_weights.items():
        print(f"Class '{class_name}': {weight:.4f}")
    
    return class_weights

# %%
class_weights = calculate_class_weights(class_counts)
# Out:
# Class weights:
# Class 'normal': 0.5908
# Class 'blast': 0.5980
# Class 'hispa': 0.6503
# Class 'dead_heart': 0.7231
# Class 'tungro': 0.9568
# Class 'brown_spot': 1.0843
# Class 'downy_mildew': 1.6720
# Class 'bacterial_leaf_blight': 2.1938
# Class 'bacterial_leaf_streak': 2.7192
# Class 'bacterial_panicle_blight': 3.0753

# %% [markdown]
# Matching the class weight to the indices generated by the data gen function

# %%
def map_weights_to_generator_indices(class_weights, generator_class_indices):
    index_weights = {} # Create a new dictionary with generator indices as keys
    
    for class_name, weight in class_weights.items(): # Map each class weight to its corresponding generator index
        if class_name in generator_class_indices:
            index = generator_class_indices[class_name]
            index_weights[index] = weight
        else:
            print(f"Warning: Class '{class_name}' not found in generator indices")
    
    for class_name, index in generator_class_indices.items():     # Verify all generator classes have weights
        if index not in index_weights:
            print(f"Warning: No weight assigned for generator class '{class_name}' (index {index})")
    
    return index_weights

# Get the generator's class indices
generator_class_indices = train_gen.class_indices
print("Generator class indices:", generator_class_indices)

# Map your calculated weights to the generator indices
index_weights = map_weights_to_generator_indices(class_weights, generator_class_indices)
print("\nMapped index weights:")
for index, weight in sorted(index_weights.items(), key=lambda x: x[0]):
    print(f"Index {index}: {weight:.4f}")
# Out:
# Generator class indices: {'bacterial_leaf_blight': 0, 'bacterial_leaf_streak': 1, 'bacterial_panicle_blight': 2, 'blast': 3, 'brown_spot': 4, 'dead_heart': 5, 'downy_mildew': 6, 'hispa': 7, 'normal': 8, 'tungro': 9}
#
# Mapped index weights:
# Index 0: 2.1938
# Index 1: 2.7192
# Index 2: 3.0753
# Index 3: 0.5980
# Index 4: 1.0843
# Index 5: 0.7231
# Index 6: 1.6720
# Index 7: 0.6503
# Index 8: 0.5908
# Index 9: 0.9568

# %% [markdown]
# ### Callback functions for training monitoring and improvement

# %% [markdown]
# Callbacks for Monitoring NaN Values

# %%
class TerminateNaN(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        loss = logs.get('loss')
        if loss is not None:
            if np.isnan(loss) or np.isinf(loss):
                print(f"Invalid loss and terminated at loss {loss}; epoch: {epoch}")
                self.model.stop_training = True

terminate_nan = TerminateNaN()

# %% [markdown]
# Model Checkpoint for Saving best models

# %%
# Save model after every epoch if the validation accuracy improves from previous epoch
cnn_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model/task1_cnn_model.h5',
    monitor="val_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    save_freq='epoch'
)

mobile_net_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model/task1_mobile_net_model.h5',
    monitor="val_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    save_freq='epoch'
)

# %% [markdown]
# Standard Learning Rate Reduction

# %%
# Standard learning rate reduction on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_categorical_accuracy",
    factor=0.1,
    patience=3,
    verbose=1,
    mode="auto",
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6
)

# %% [markdown]
# Early Stopping

# %%
# Early stopping with baseline performance requirement
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_categorical_accuracy',
    min_delta=0.001,
    patience=8,
    verbose=1,
    mode='auto',
    baseline=0.75,  # Only consider stopping if accuracy is above this threshold
    restore_best_weights=True
)

# %% [markdown]
# CSV Logger for Training History

# %%
# CSV logger to save training metrics to file
cnn_csv_logger = tf.keras.callbacks.CSVLogger(
    filename='logs/cnn_training_history.csv',
    separator=',',
    append=True
)

mobile_net_csv_logger = tf.keras.callbacks.CSVLogger(
    filename='logs/mobile_net_training_history.csv',
    separator=',',
    append=True
)

# %% [markdown]
# ### CNN Model

# %%
# input_shape = (BATCH_SIZE,IMAGE_SHAPE,3) 
# BATCH_SIZE = 32
# IMAGE_SHAPE = (244,244)

cnn_model = models.Sequential([
        # First convolutional block
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(244, 244, 3)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        
        # Second convolutional block
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        
        # Third convolutional block
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        
        # Flatten and dense layers
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),  # Add dropout to prevent overfitting
        layers.Dense(10, activation='softmax')
    ])

# Compile the model
cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name="categorical_accuracy")]
)

cnn_model.summary()

# %%
cnn_history = model.fit(
    train_gen,
    batch_size = batch_size,
    validation_data = valid_gen,
    epochs=100,
    verbose=1,
    class_weight=index_weights,
    callbacks=[terminate_nan, cnn_checkpoint, reduce_lr, early_stopping, cnn_csv_logger]
)

# %% [markdown]
# ### MobileNetV2

# %%
# Create base MobileNetV2 model without top layer
base_model = MobileNetV2(
    include_top=False,
    input_shape=input_shape,
    weights='imagenet' # set to None
)
base_model.trainable = True
inputs = layers.Input(shape=(244,244,3)) # Create input layer

x = mobile_net_model(inputs, training = True)
x = layers.Flatten()(x)
x = layers.Dense(256, 'relu', kernel_initializer='he_normal')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax', name= 'outputs')(x) # 10 classes 

mobile_net_model = Model(inputs= [inputs], outputs= [outputs])

mobile_net_model.compile(optimizer=optimizers.Adam(3e-4), 
              metrics=[tf.keras.metrics.CategoricalAccuracy(name="categorical_accuracy", dtype=None)], 
              loss=losses.CategoricalCrossentropy(label_smoothing=0.1))

mobile_net_model.summary()

# %%
mobile_net_history = mobile_net_model.fit(
    train_gen,
    batch_size = batch_size,
    validation_data = valid_gen,
    epochs=100,
    verbose=1,
    class_weight=index_weights,
    callbacks=[terminate_nan, mobile_net_checkpoint, reduce_lr, early_stopping, mobile_net_csv_logger]
)

# %% [markdown]
# ### Evaluation Function

# %%
def evaluate_model(model, history):
    # Plot training history
    plt.figure(figsize=(12, 4))
    
    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['categorical_accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Return the best validation accuracy
    best_val_acc = max(history.history['val_categorical_accuracy'])
    print(f"Best validation accuracy: {best_val_acc:.4f}")
    
    return best_val_acc

# %% [markdown]
# For CNN Model

# %%
cnn_val_acc = evaluate_model(cnn_model, cnn_history)

# %% [markdown]
# For Mobile Net Model

# %%
mobile_net_val_acc = evaluate_model(mobile_net_model, mobile_net_history)
