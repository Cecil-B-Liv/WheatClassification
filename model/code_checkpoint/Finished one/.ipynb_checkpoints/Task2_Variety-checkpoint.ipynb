# %% [markdown]
# # Importing Library

# %% [markdown]
# ## Pip install thing (just to shorten the installation log)

# %%
# !pip install --user tensorflow==2.17
# !pip install --user matplotlib
# !pip install --user tensorflow-hub
# !pip install --user scikit-learn
# !pip install --user numpy==1.26.4 
# !pip install --user seaborn

# %% [markdown]
# ## Importing Library

# %% [markdown]
# ### Run this if you're on Jupyter Lab

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import os
import seaborn as sns
import glob
import cv2
import zipfile
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Sequential  # Sequential API for building models layer by layer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, EfficientNetB0
import shutil
from PIL import Image
import hashlib
import random
from pathlib import Path
from tqdm import tqdm
from tensorflow.keras.callbacks import TensorBoard, CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

import warnings
warnings.filterwarnings('ignore')

print("TF version:", tf.__version__)
# print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Check for GPU availability in TensorFlow
device = "GPU" if len(tf.config.list_physical_devices('GPU')) > 0 else "CPU"
print("The device is:", device)

# rm -rf '/content/__MACOSX'
# use this one when you need to remove folder and not getting must be empty error
# Out:
# TF version: 2.10.0
# GPU is available
# The device is: GPU

# %% [markdown]
# # Extracting Data

# %% [markdown]
# ### Loading and Unzipping Data From Drive

# %%
# Define the extraction paths
train_extract_path = 'dataset/train_images/'
test_extract_path = 'dataset/test_images/'

# For train images: remove if exists, then extract
if os.path.exists(train_extract_path):
    print(f"Removing existing train images folder: {train_extract_path}")
    shutil.rmtree(train_extract_path)
    
# Create directory if it doesn't exist
os.makedirs(train_extract_path, exist_ok=True)

# Extract train images
with zipfile.ZipFile('zip_data/train_images.zip', 'r') as train_zip_ref:
    print("Extracting train images...")
    train_zip_ref.extractall(train_extract_path)
    print("Train images extracted successfully.")

# For test images: remove if exists, then extract
if os.path.exists(test_extract_path):
    print(f"Removing existing test images folder: {test_extract_path}")
    shutil.rmtree(test_extract_path)
    
# Create directory if it doesn't exist
os.makedirs(test_extract_path, exist_ok=True)

# Extract test images
with zipfile.ZipFile('zip_data/test_images.zip', 'r') as test_zip_ref:
    print("Extracting test images...")
    test_zip_ref.extractall(test_extract_path)
    print("Test images extracted successfully.")

print("All extraction complete!")
# Out:
# Removing existing train images folder: dataset/train_images/
# Extracting train images...
# Train images extracted successfully.
# Removing existing test images folder: dataset/test_images/
# Extracting test images...
# Test images extracted successfully.
# All extraction complete!

# %% [markdown]
# ### Check Class Names

# %%
CLASS_NAMES = [os.path.basename(l) for l in glob.glob('dataset/train_images/train_images/*')
               if '.' not in l]
# CLASS_NAMES = [os.path.basename(l) for l in glob.glob('/content/drive/MyDrive/Colab Notebooks/train_images/train_images/*')
#                if '.' not in l]  ## if on google colab
print(CLASS_NAMES)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %% [markdown]
# ### Load CSV file

# %%
# train_df = pd.read_csv('/content/drive/MyDrive/Dataset/meta_train.csv')
train_df = pd.read_csv('opencv/meta_train.csv')
train_df
# Out:
#          image_id                  label variety  age
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
# [10407 rows x 4 columns]

# %% [markdown]
# Map the path depending on the label first

# %%
# train_df['path'] = '/content/drive/MyDrive/Colab Notebooks/train_images/' + train_df['label'] + "/" + train_df["image_id"]
train_df['path'] = 'dataset/train_images/train_images/' + train_df['label'] + "/" + train_df["image_id"]
train_df.head()
# Out:
#      image_id                  label variety  age  \
# 0  100330.jpg  bacterial_leaf_blight   ADT45   45
# 1  100365.jpg  bacterial_leaf_blight   ADT45   45
# 2  100382.jpg  bacterial_leaf_blight   ADT45   45
# 3  100632.jpg  bacterial_leaf_blight   ADT45   45
# 4  101918.jpg  bacterial_leaf_blight   ADT45   45
#
#                                                 path
# 0  dataset/train_images/train_images/bacterial_le...
# 1  dataset/train_images/train_images/bacterial_le...
# 2  dataset/train_images/train_images/bacterial_le...
# 3  dataset/train_images/train_images/bacterial_le...
# 4  dataset/train_images/train_images/bacterial_le...

# %% [markdown]
# # Data Loading and Preprocessing

# %% [markdown]
# ### Check Duplicates in dataset

# %%
def calculate_hash(image_path):
    with Image.open(image_path) as img:
        return hashlib.md5(img.tobytes()).hexdigest()

def find_duplicates_in_dataset(root_folder):
    hashes = {}
    duplicates = []

    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(('.png', '.jpg')):
                path = os.path.join(subdir, file)
                try:
                    file_hash = calculate_hash(path)
                    if file_hash in hashes:
                        duplicates.append((path, hashes[file_hash]))
                    else:
                        hashes[file_hash] = path
                except Exception as e:
                    print(f"Error processing {file}: {e}")
    
    return duplicates
    
# Function to delete duplicate files, keeping only the first occurrence
def remove_duplicate_files(duplicates):
    removed_count = 0
    for duplicate_path, original_path in duplicates:
        try:
            # Check if file exists before attempting to remove
            if os.path.exists(duplicate_path):
                os.remove(duplicate_path)
                print(f"Removed: {duplicate_path}")
                removed_count += 1
            else:
                print(f"File not found: {duplicate_path}")
        except Exception as e:
            print(f"Error removing {duplicate_path}: {e}")
    
    return removed_count

duplicates = find_duplicates_in_dataset('dataset/train_images/train_images/')
for dup1, dup2 in duplicates:
    print(f"Duplicate found:\n -> {dup1}\n -> {dup2}\n")
# Out:
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\100513.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\100169.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\103032.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\100133.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\104800.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\102353.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\105878.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\103344.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\106984.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\100998.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\107812.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\100635.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\108125.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\102038.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_leaf_blight\108353.jpg
#  -> dataset/train_images/train_images/bacterial_leaf_blight\101173.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/bacterial_panicle_blight\104803.jpg
#  -> dataset/train_images/train_images/bacterial_panicle_blight\104320.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\102705.jpg
#  -> dataset/train_images/train_images/blast\102334.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\105626.jpg
#  -> dataset/train_images/train_images/blast\104586.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\105840.jpg
#  -> dataset/train_images/train_images/blast\101343.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\105962.jpg
#  -> dataset/train_images/train_images/blast\101483.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\106520.jpg
#  -> dataset/train_images/train_images/blast\106102.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\107069.jpg
#  -> dataset/train_images/train_images/blast\100501.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\108455.jpg
#  -> dataset/train_images/train_images/blast\108403.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\108989.jpg
#  -> dataset/train_images/train_images/blast\100522.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\109346.jpg
#  -> dataset/train_images/train_images/blast\104021.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/blast\109773.jpg
#  -> dataset/train_images/train_images/blast\105038.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\102827.jpg
#  -> dataset/train_images/train_images/brown_spot\100939.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\104373.jpg
#  -> dataset/train_images/train_images/brown_spot\102063.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\104862.jpg
#  -> dataset/train_images/train_images/brown_spot\102938.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\105245.jpg
#  -> dataset/train_images/train_images/brown_spot\103128.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\105916.jpg
#  -> dataset/train_images/train_images/brown_spot\105649.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\106948.jpg
#  -> dataset/train_images/train_images/brown_spot\105169.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\107005.jpg
#  -> dataset/train_images/train_images/brown_spot\106596.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\107088.jpg
#  -> dataset/train_images/train_images/brown_spot\105194.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\108604.jpg
#  -> dataset/train_images/train_images/brown_spot\103415.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\109494.jpg
#  -> dataset/train_images/train_images/brown_spot\106860.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\109596.jpg
#  -> dataset/train_images/train_images/brown_spot\101456.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/brown_spot\110157.jpg
#  -> dataset/train_images/train_images/brown_spot\102859.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\103245.jpg
#  -> dataset/train_images/train_images/dead_heart\101021.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\103299.jpg
#  -> dataset/train_images/train_images/dead_heart\100206.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\103591.jpg
#  -> dataset/train_images/train_images/dead_heart\103195.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\104196.jpg
#  -> dataset/train_images/train_images/dead_heart\103215.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\106209.jpg
#  -> dataset/train_images/train_images/dead_heart\101578.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\106481.jpg
#  -> dataset/train_images/train_images/dead_heart\101868.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\106924.jpg
#  -> dataset/train_images/train_images/dead_heart\103329.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\107011.jpg
#  -> dataset/train_images/train_images/dead_heart\104957.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\107569.jpg
#  -> dataset/train_images/train_images/dead_heart\103001.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\108094.jpg
#  -> dataset/train_images/train_images/dead_heart\107526.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\109458.jpg
#  -> dataset/train_images/train_images/dead_heart\101222.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\110000.jpg
#  -> dataset/train_images/train_images/dead_heart\101868.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/dead_heart\110040.jpg
#  -> dataset/train_images/train_images/dead_heart\107311.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/downy_mildew\107847.jpg
#  -> dataset/train_images/train_images/downy_mildew\103260.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/downy_mildew\108591.jpg
#  -> dataset/train_images/train_images/downy_mildew\100017.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/hispa\101948.jpg
#  -> dataset/train_images/train_images/hispa\101512.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/hispa\106309.jpg
#  -> dataset/train_images/train_images/hispa\105621.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/hispa\107078.jpg
#  -> dataset/train_images/train_images/hispa\104143.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/hispa\108832.jpg
#  -> dataset/train_images/train_images/hispa\101788.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/hispa\109935.jpg
#  -> dataset/train_images/train_images/hispa\108645.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\100602.jpg
#  -> dataset/train_images/train_images/normal\100007.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\102440.jpg
#  -> dataset/train_images/train_images/normal\100285.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\104451.jpg
#  -> dataset/train_images/train_images/normal\100844.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\104484.jpg
#  -> dataset/train_images/train_images/normal\100737.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\106265.jpg
#  -> dataset/train_images/train_images/normal\100844.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107152.jpg
#  -> dataset/train_images/train_images/normal\106308.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107379.jpg
#  -> dataset/train_images/train_images/normal\101331.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107385.jpg
#  -> dataset/train_images/train_images/normal\102598.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107675.jpg
#  -> dataset/train_images/train_images/normal\105315.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107872.jpg
#  -> dataset/train_images/train_images/normal\103763.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\107897.jpg
#  -> dataset/train_images/train_images/normal\100344.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\108015.jpg
#  -> dataset/train_images/train_images/normal\104634.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\109156.jpg
#  -> dataset/train_images/train_images/normal\101562.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\109634.jpg
#  -> dataset/train_images/train_images/normal\102843.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/normal\109805.jpg
#  -> dataset/train_images/train_images/normal\106366.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\104027.jpg
#  -> dataset/train_images/train_images/tungro\100100.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\104901.jpg
#  -> dataset/train_images/train_images/tungro\100689.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\105747.jpg
#  -> dataset/train_images/train_images/tungro\103091.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\106461.jpg
#  -> dataset/train_images/train_images/tungro\101739.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\106650.jpg
#  -> dataset/train_images/train_images/tungro\105231.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\106818.jpg
#  -> dataset/train_images/train_images/tungro\104116.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\107269.jpg
#  -> dataset/train_images/train_images/tungro\101086.jpg
#
# Duplicate found:
#  -> dataset/train_images/train_images/tungro\107641.jpg
#  -> dataset/train_images/train_images/tungro\101445.jpg

# %% [markdown]
# Then we will remove these dulpicate ones from the dataframe
# Then we need to remove it from the dataset as well.

# %%
# Remove the duplicate files from the filesystem
if duplicates:
    removed_count = remove_duplicate_files(duplicates)
    print(f"\nRemoved {removed_count} duplicate image files")
else:
    print("No duplicates found.")

# If you also need to update your dataframe after removing files
if 'train_df' in locals() or 'train_df' in globals():
    # Extract ONLY the duplicate paths (not the originals) to remove from dataframe
    paths_to_remove = [duplicate_path for duplicate_path, original_path in duplicates]
    
    # Normalize paths to ensure consistent comparison
    train_df['path'] = train_df['path'].apply(os.path.normpath)
    paths_to_remove = [os.path.normpath(path) for path in paths_to_remove]
    
    # Remove only the duplicate entries from dataframe
    original_length = len(train_df)
    train_df = train_df[~train_df['path'].isin(paths_to_remove)].reset_index(drop=True)
    removed_count = original_length - len(train_df)
    
    print(f"Removed {removed_count} duplicate image entries from dataframe")
# Out:
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\100513.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\103032.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\104800.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\105878.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\106984.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\107812.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\108125.jpg
# Removed: dataset/train_images/train_images/bacterial_leaf_blight\108353.jpg
# Removed: dataset/train_images/train_images/bacterial_panicle_blight\104803.jpg
# Removed: dataset/train_images/train_images/blast\102705.jpg
# Removed: dataset/train_images/train_images/blast\105626.jpg
# Removed: dataset/train_images/train_images/blast\105840.jpg
# Removed: dataset/train_images/train_images/blast\105962.jpg
# Removed: dataset/train_images/train_images/blast\106520.jpg
# Removed: dataset/train_images/train_images/blast\107069.jpg
# Removed: dataset/train_images/train_images/blast\108455.jpg
# Removed: dataset/train_images/train_images/blast\108989.jpg
# Removed: dataset/train_images/train_images/blast\109346.jpg
# Removed: dataset/train_images/train_images/blast\109773.jpg
# Removed: dataset/train_images/train_images/brown_spot\102827.jpg
# Removed: dataset/train_images/train_images/brown_spot\104373.jpg
# Removed: dataset/train_images/train_images/brown_spot\104862.jpg
# Removed: dataset/train_images/train_images/brown_spot\105245.jpg
# Removed: dataset/train_images/train_images/brown_spot\105916.jpg
# Removed: dataset/train_images/train_images/brown_spot\106948.jpg
# Removed: dataset/train_images/train_images/brown_spot\107005.jpg
# Removed: dataset/train_images/train_images/brown_spot\107088.jpg
# Removed: dataset/train_images/train_images/brown_spot\108604.jpg
# Removed: dataset/train_images/train_images/brown_spot\109494.jpg
# Removed: dataset/train_images/train_images/brown_spot\109596.jpg
# Removed: dataset/train_images/train_images/brown_spot\110157.jpg
# Removed: dataset/train_images/train_images/dead_heart\103245.jpg
# Removed: dataset/train_images/train_images/dead_heart\103299.jpg
# Removed: dataset/train_images/train_images/dead_heart\103591.jpg
# Removed: dataset/train_images/train_images/dead_heart\104196.jpg
# Removed: dataset/train_images/train_images/dead_heart\106209.jpg
# Removed: dataset/train_images/train_images/dead_heart\106481.jpg
# Removed: dataset/train_images/train_images/dead_heart\106924.jpg
# Removed: dataset/train_images/train_images/dead_heart\107011.jpg
# Removed: dataset/train_images/train_images/dead_heart\107569.jpg
# Removed: dataset/train_images/train_images/dead_heart\108094.jpg
# Removed: dataset/train_images/train_images/dead_heart\109458.jpg
# Removed: dataset/train_images/train_images/dead_heart\110000.jpg
# Removed: dataset/train_images/train_images/dead_heart\110040.jpg
# Removed: dataset/train_images/train_images/downy_mildew\107847.jpg
# Removed: dataset/train_images/train_images/downy_mildew\108591.jpg
# Removed: dataset/train_images/train_images/hispa\101948.jpg
# Removed: dataset/train_images/train_images/hispa\106309.jpg
# Removed: dataset/train_images/train_images/hispa\107078.jpg
# Removed: dataset/train_images/train_images/hispa\108832.jpg
# Removed: dataset/train_images/train_images/hispa\109935.jpg
# Removed: dataset/train_images/train_images/normal\100602.jpg
# Removed: dataset/train_images/train_images/normal\102440.jpg
# Removed: dataset/train_images/train_images/normal\104451.jpg
# Removed: dataset/train_images/train_images/normal\104484.jpg
# Removed: dataset/train_images/train_images/normal\106265.jpg
# Removed: dataset/train_images/train_images/normal\107152.jpg
# Removed: dataset/train_images/train_images/normal\107379.jpg
# Removed: dataset/train_images/train_images/normal\107385.jpg
# Removed: dataset/train_images/train_images/normal\107675.jpg
# Removed: dataset/train_images/train_images/normal\107872.jpg
# Removed: dataset/train_images/train_images/normal\107897.jpg
# Removed: dataset/train_images/train_images/normal\108015.jpg
# Removed: dataset/train_images/train_images/normal\109156.jpg
# Removed: dataset/train_images/train_images/normal\109634.jpg
# Removed: dataset/train_images/train_images/normal\109805.jpg
# Removed: dataset/train_images/train_images/tungro\104027.jpg
# Removed: dataset/train_images/train_images/tungro\104901.jpg
# Removed: dataset/train_images/train_images/tungro\105747.jpg
# Removed: dataset/train_images/train_images/tungro\106461.jpg
# Removed: dataset/train_images/train_images/tungro\106650.jpg
# Removed: dataset/train_images/train_images/tungro\106818.jpg
# Removed: dataset/train_images/train_images/tungro\107269.jpg
# Removed: dataset/train_images/train_images/tungro\107641.jpg
#
# Removed 74 duplicate image files
# Removed 74 duplicate image entries from dataframe

# %% [markdown]
# ### Sorted into folder according to their variety

# %%
# Define output directory
output_base_dir = 'dataset/train_images_by_variety'

# Reset the output directory if it exists
if os.path.exists(output_base_dir):
    shutil.rmtree(output_base_dir)
    print(f"Removed existing directory: {output_base_dir}")

# Recreate the base output directory
os.makedirs(output_base_dir, exist_ok=True)

# Get unique varieties
varieties = train_df['variety'].unique()
print(f"Found {len(varieties)} unique varieties: {varieties}")

# Create directories for each variety
for variety in varieties:
    variety_dir = os.path.join(output_base_dir, variety)
    os.makedirs(variety_dir, exist_ok=True)

# Copy files to their new locations
print("Copying images to variety folders...")
for idx, row in tqdm(train_df.iterrows(), total=len(train_df)):
    src_path = row['path']
    dst_path = os.path.join(output_base_dir, row['variety'], row['image_id'])
    
    try:
        shutil.copy2(src_path, dst_path)
    except FileNotFoundError:
        print(f"Warning: Could not find {src_path}")

print("Done. Images have been sorted into directories by variety.")
print(f"New directory structure: {output_base_dir}/[variety]/[image_id]")

# Verify image count per variety
for variety in varieties:
    variety_dir = os.path.join(output_base_dir, variety)
    file_count = len([f for f in os.listdir(variety_dir) if os.path.isfile(os.path.join(variety_dir, f))])
    print(f"Variety '{variety}': {file_count} images")
# Out:
# Removed existing directory: dataset/train_images_by_variety
# Found 10 unique varieties: ['ADT45' 'IR20' 'KarnatakaPonni' 'Onthanel' 'Ponni' 'Surya' 'Zonal'
#  'AndraPonni' 'AtchayaPonni' 'RR']
# Copying images to variety folders...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10333/10333 [00:09<00:00, 1107.82it/s]
# Done. Images have been sorted into directories by variety.
# New directory structure: dataset/train_images_by_variety/[variety]/[image_id]
# Variety 'ADT45': 6930 images
# Variety 'IR20': 113 images
# Variety 'KarnatakaPonni': 982 images
# Variety 'Onthanel': 349 images
# Variety 'Ponni': 656 images
# Variety 'Surya': 32 images
# Variety 'Zonal': 399 images
# Variety 'AndraPonni': 376 images
# Variety 'AtchayaPonni': 460 images
# Variety 'RR': 36 images

# %% [markdown]
# ### Map the csv depending on the variety

# %%
train_df = train_df.drop('path', axis=1)
train_df['path'] = 'dataset/train_images_by_variety/' + train_df['variety'] + "/" + train_df["image_id"]
train_df.head()
# Out:
#      image_id                  label variety  age  \
# 0  100330.jpg  bacterial_leaf_blight   ADT45   45
# 1  100365.jpg  bacterial_leaf_blight   ADT45   45
# 2  100382.jpg  bacterial_leaf_blight   ADT45   45
# 3  100632.jpg  bacterial_leaf_blight   ADT45   45
# 4  101918.jpg  bacterial_leaf_blight   ADT45   45
#
#                                                path
# 0  dataset/train_images_by_variety/ADT45/100330.jpg
# 1  dataset/train_images_by_variety/ADT45/100365.jpg
# 2  dataset/train_images_by_variety/ADT45/100382.jpg
# 3  dataset/train_images_by_variety/ADT45/100632.jpg
# 4  dataset/train_images_by_variety/ADT45/101918.jpg

# %%
train_df
# Out:
#          image_id                  label variety  age  \
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10328  107607.jpg                 tungro   Zonal   55
# 10329  107811.jpg                 tungro   Zonal   55
# 10330  108547.jpg                 tungro   Zonal   55
# 10331  110245.jpg                 tungro   Zonal   55
# 10332  110381.jpg                 tungro   Zonal   55
#
#                                                    path
# 0      dataset/train_images_by_variety/ADT45/100330.jpg
# 1      dataset/train_images_by_variety/ADT45/100365.jpg
# 2      dataset/train_images_by_variety/ADT45/100382.jpg
# 3      dataset/train_images_by_variety/ADT45/100632.jpg
# 4      dataset/train_images_by_variety/ADT45/101918.jpg
# ...                                                 ...
# 10328  dataset/train_images_by_variety/Zonal/107607.jpg
# 10329  dataset/train_images_by_variety/Zonal/107811.jpg
# 10330  dataset/train_images_by_variety/Zonal/108547.jpg
# 10331  dataset/train_images_by_variety/Zonal/110245.jpg
# 10332  dataset/train_images_by_variety/Zonal/110381.jpg
#
# [10333 rows x 5 columns]

# %% [markdown]
# ### Data Distribution

# %%
# Visualize class distribution
plt.figure(figsize=(12, 6))
class_counts = train_df['variety'].value_counts()
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class Distribution in Training Data')
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Print the exact counts
print("Class distribution:")
for variety, count in class_counts.items():
    print(f"{variety}: {count} samples ({count/len(train_df)*100:.2f}%)")
# Out:
# Class distribution:
# ADT45: 6930 samples (67.07%)
# KarnatakaPonni: 982 samples (9.50%)
# Ponni: 656 samples (6.35%)
# AtchayaPonni: 460 samples (4.45%)
# Zonal: 399 samples (3.86%)
# AndraPonni: 376 samples (3.64%)
# Onthanel: 349 samples (3.38%)
# IR20: 113 samples (1.09%)
# RR: 36 samples (0.35%)
# Surya: 32 samples (0.31%)

# %%
def check_total_images(data_dir):
    """
    Prints the number of images per class and the total in the dataset directory.
    """
    total = 0
    print("Image Count Per Class:")
    print("-" * 30)
    for class_name in sorted(os.listdir(data_dir)):
        class_path = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_path):
            continue

        count = len([f for f in os.listdir(class_path) if f.endswith('.jpg')])
        total += count
        print(f"{class_name:25}: {count} images")
    print("-" * 30)
    print(f"Total images in dataset: {total}")

check_total_images('dataset/train_images_by_variety/')
# Out:
# Image Count Per Class:
# ------------------------------
# ADT45                    : 6930 images
# AndraPonni               : 376 images
# AtchayaPonni             : 460 images
# IR20                     : 113 images
# KarnatakaPonni           : 982 images
# Onthanel                 : 349 images
# Ponni                    : 656 images
# RR                       : 36 images
# Surya                    : 32 images
# Zonal                    : 399 images
# ------------------------------
# Total images in dataset: 10333

# %% [markdown]
# ## New Test Data Augmentating

# %%
# latent_dim = 100
# image_height, image_width, image_channels = 32, 32, 3

# def make_generator():
#     model = tf.keras.Sequential([
#         layers.Dense(4*4*512, input_shape=(latent_dim,)),
#         layers.Reshape((4, 4, 512)),
#         layers.BatchNormalization(),
#         layers.LeakyReLU(),

#         layers.Conv2DTranspose(256, 4, strides=2, padding='same'),
#         layers.BatchNormalization(),
#         layers.LeakyReLU(),  # 8x8x256

#         layers.Conv2DTranspose(128, 4, strides=2, padding='same'),
#         layers.BatchNormalization(),
#         layers.LeakyReLU(),  # 16x16x128

#         layers.Conv2DTranspose(64, 4, strides=2, padding='same'),
#         layers.BatchNormalization(),
#         layers.LeakyReLU(),  # 32x32x64

#         layers.Conv2DTranspose(3, 4, strides=2, padding='same', activation='tanh')  # 💥 64x64x3
#     ])
#     return model

# def make_discriminator():
#     model = tf.keras.Sequential([
#         layers.Conv2D(64, 4, strides=2, padding='same', input_shape=(64, 64, 3)),
#         layers.LeakyReLU(),
#         layers.Dropout(0.3),

#         layers.Conv2D(128, 4, strides=2, padding='same'),
#         layers.LeakyReLU(),
#         layers.Dropout(0.3),

#         layers.Conv2D(256, 4, strides=2, padding='same'),
#         layers.LeakyReLU(),
#         layers.Dropout(0.3),

#         layers.Flatten(),
#         layers.Dense(1, activation='sigmoid')
#     ])
#     return model
    
# loss_fn = tf.keras.losses.BinaryCrossentropy()
# gen_opt = tf.keras.optimizers.Adam(0.0002, beta_1=0.5)
# disc_opt = tf.keras.optimizers.Adam(0.0002, beta_1=0.5)

# %%
# def train_gan(dataset, epochs=50):
#     generator = make_generator()
#     discriminator = make_discriminator()

#     # Move these INSIDE so they reset for each new GAN
#     gen_opt = tf.keras.optimizers.Adam(0.0002, beta_1=0.5)
#     disc_opt = tf.keras.optimizers.Adam(0.0002, beta_1=0.5)

#     # Define training step inside this function to access the fresh optimizers
#     @tf.function
#     def train_step(images):
#         noise = tf.random.normal([tf.shape(images)[0], latent_dim])
#         with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
#             fake_images = generator(noise, training=True)
#             real_out = discriminator(images, training=True)
#             fake_out = discriminator(fake_images, training=True)

#             gen_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_out), fake_out)
#             disc_loss = (
#                 tf.keras.losses.binary_crossentropy(tf.ones_like(real_out), real_out) +
#                 tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_out), fake_out)
#             )

#         gen_grad = gen_tape.gradient(gen_loss, generator.trainable_variables)
#         disc_grad = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
#         gen_opt.apply_gradients(zip(gen_grad, generator.trainable_variables))
#         disc_opt.apply_gradients(zip(disc_grad, discriminator.trainable_variables))

#     for epoch in range(epochs):
#         for batch in dataset:
#             train_step(batch)

#     return generator

# def load_images_for_gan(class_path, target_shape=(64, 64)):
#     images = []
#     for fname in os.listdir(class_path):
#         if not fname.lower().endswith('.jpg'):
#             continue
#         img = Image.open(os.path.join(class_path, fname)).resize(target_shape)
#         img_array = np.array(img)
#         if img_array.shape != (64, 64, 3):
#             continue
#         images.append(img_array)
#     images = np.array(images).astype('float32')
#     images = (images - 127.5) / 127.5  # Normalize to [-1, 1]
#     return images

# def augment_with_gan(class_name, num_to_generate, class_folder):
#     print(f"[GAN] Generating {num_to_generate} images for '{class_name}'")
#     images = load_images_for_gan(class_folder)

#     if len(images) < 10:
#         print(f"Not enough images to train GAN for '{class_name}'. Skipping.")
#         return

#     dataset = tf.data.Dataset.from_tensor_slices(images).shuffle(500).batch(32)
#     generator = train_gan(dataset)

#     noise = tf.random.normal([num_to_generate, latent_dim])
#     synthetic_imgs = generator(noise, training=False)
#     synthetic_imgs = ((synthetic_imgs + 1) * 127.5).numpy().astype('uint8')

#     for i, img_array in enumerate(synthetic_imgs):
#         img = Image.fromarray(img_array)
#         img.save(os.path.join(class_folder, f'gan_{i}.jpg'))

# %%
# train_data_path = 'dataset/train_images_by_variety/'
# underrepresented = ['Surya', 'RR', 'IR20', 'Onthanel', 'AndraPonni', 'Zonal']

# # Count current images per class
# class_counts = {}
# for class_name in os.listdir(train_data_path):
#     class_path = os.path.join(train_data_path, class_name)
#     if not os.path.isdir(class_path): continue
#     images = [f for f in os.listdir(class_path) if f.endswith('.jpg')]
#     class_counts[class_name] = len(images)

# average_count = int(np.mean(list(class_counts.values())))
# print(f"Target image count per class: {average_count}")

# # Apply GAN augmentation
# for class_name in underrepresented:
#     if class_name not in class_counts:
#         continue
#     current = class_counts[class_name]
#     needed = average_count - current
#     if needed > 0:
#         class_path = os.path.join(train_data_path, class_name)
#         augment_with_gan(class_name, needed, class_path)

# %% [markdown]
# ## Augmentating the Data before Splitting and Loading

# %%
train_data_path = 'dataset/train_images_by_variety/'

# Step 1: Count images per class
class_counts = {}
for class_name in os.listdir(train_data_path):
    class_path = os.path.join(train_data_path, class_name)
    if not os.path.isdir(class_path): continue
    image_files = [f for f in os.listdir(class_path) if f.endswith('.jpg')]
    class_counts[class_name] = len(image_files)

# Step 2: Define augmentation
augmentor = ImageDataGenerator(
    rotation_range=30,               # More rotation
    shear_range=0.3,                 # Stronger shearing
    zoom_range=[0.6, 1.4],           # Bigger zoom range (zoom in & out)
    width_shift_range=0.3,
    height_shift_range=0.3,
    brightness_range=(0.4, 1.6),     # Drastic brightness changes
    channel_shift_range=30.0,        # Deep color shifts
    horizontal_flip=True,
    vertical_flip=True,              # Enable if orientation doesn't matter
    fill_mode='nearest'
)

average_count = int(np.mean(list(class_counts.values())))
print(f"Target image count per class: {average_count}")

# Step 3: Augment classes below the average
for class_name, count in class_counts.items():
    if count >= average_count:
        print(f"Skipping '{class_name}' (already has {count} images)")
        continue

    class_path = os.path.join(train_data_path, class_name)
    images = [f for f in os.listdir(class_path) if f.endswith('.jpg')]
    current_count = count
    augment_index = 0

    print(f"Augmenting '{class_name}' from {current_count} to {average_count}")
    pbar = tqdm(total=average_count - current_count)

    while current_count < average_count:
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            img = load_img(img_path)
            x = img_to_array(img).reshape((1,) + img_to_array(img).shape)

            batch = next(augmentor.flow(x, batch_size=1))
            new_img = array_to_img(batch[0])
            new_img.save(os.path.join(class_path, f'aug_{augment_index}.jpg'))

            current_count += 1
            augment_index += 1
            pbar.update(1)

            if current_count >= average_count:
                break

    pbar.close()
# Out:
# Target image count per class: 1033
# Skipping 'ADT45' (already has 6930 images)
# Augmenting 'AndraPonni' from 376 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 657/657 [00:41<00:00, 15.99it/s]
# Augmenting 'AtchayaPonni' from 460 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 573/573 [00:36<00:00, 15.91it/s]
# Augmenting 'IR20' from 113 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 920/920 [00:54<00:00, 16.75it/s]
# Augmenting 'KarnatakaPonni' from 982 to 1033
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:03<00:00, 15.24it/s]
# Augmenting 'Onthanel' from 349 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 684/684 [00:41<00:00, 16.44it/s]
# Augmenting 'Ponni' from 656 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 377/377 [00:24<00:00, 15.55it/s]
# Augmenting 'RR' from 36 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 997/997 [00:54<00:00, 18.31it/s]
# Augmenting 'Surya' from 32 to 1033
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1001/1001 [00:55<00:00, 18.03it/s]
# Augmenting 'Zonal' from 399 to 1033
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 634/634 [00:39<00:00, 15.96it/s]

# %% [markdown]
# ### Data Normalization and Data Generator

# %%
check_total_images('dataset/train_images_by_variety/')
# Out:
# Image Count Per Class:
# ------------------------------
# ADT45                    : 6930 images
# AndraPonni               : 1033 images
# AtchayaPonni             : 1033 images
# IR20                     : 1033 images
# KarnatakaPonni           : 1033 images
# Onthanel                 : 1033 images
# Ponni                    : 1033 images
# RR                       : 1033 images
# Surya                    : 1033 images
# Zonal                    : 1033 images
# ------------------------------
# Total images in dataset: 16227

# %%
BATCH_SIZE = 32
IMAGE_SHAPE = (224,224)
train_data_path = 'dataset/train_images_by_variety/'

# For training data - with augmentation
data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 80/20 split
)

# %% [markdown]
# With these parameters as data augmentation parameters, I split the dataset with the reatio of 0.8-0.2.

# %%
# For training data (with augmentation)
train_gen = data_gen.flow_from_directory(
    train_data_path,
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    subset='training',
    seed=42,
    class_mode='categorical',
    color_mode='rgb'
)
# Out:
# Found 12987 images belonging to 10 classes.

# %%
# For validation data (without augmentation)
valid_gen = data_gen.flow_from_directory(
    train_data_path,
    target_size=IMAGE_SHAPE,
    batch_size=BATCH_SIZE,
    subset='validation',
    seed=42,
    class_mode='categorical',
    color_mode='rgb'
)
# Out:
# Found 3240 images belonging to 10 classes.

# %% [markdown]
# ## Data Distribution After Augmentated

# %%
from collections import Counter

folder_counts = {}
for class_name in os.listdir(train_data_path):
    class_folder = os.path.join(train_data_path, class_name)
    if os.path.isdir(class_folder):
        count = len([f for f in os.listdir(class_folder) if f.endswith('.jpg')])
        folder_counts[class_name] = count

# Plot the distribution
plt.figure(figsize=(12, 6))
sns.barplot(x=list(folder_counts.keys()), y=list(folder_counts.values()))
plt.title('Class Distribution Based on Folder Images')
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Print counts
print("Updated Class Distribution:")
total_imgs = sum(folder_counts.values())
for label, count in folder_counts.items():
    print(f"{label}: {count} samples ({(count/total_imgs)*100:.2f}%)")
# Out:
# Updated Class Distribution:
# ADT45: 6930 samples (42.71%)
# AndraPonni: 1033 samples (6.37%)
# AtchayaPonni: 1033 samples (6.37%)
# IR20: 1033 samples (6.37%)
# KarnatakaPonni: 1033 samples (6.37%)
# Onthanel: 1033 samples (6.37%)
# Ponni: 1033 samples (6.37%)
# RR: 1033 samples (6.37%)
# Surya: 1033 samples (6.37%)
# Zonal: 1033 samples (6.37%)

# %% [markdown]
# ### Data Class Weighting

# %% [markdown]
# Calculate class weighting on the dataframe

# %%
def get_class_counts_from_folders(data_dir):
    """
    Returns a dictionary with image counts per class folder.
    """
    class_counts = {}
    for class_name in os.listdir(data_dir):
        class_path = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_path):
            continue
        count = len([f for f in os.listdir(class_path) if f.endswith('.jpg')])
        class_counts[class_name] = count
    return class_counts

def calculate_class_weights(class_counts):
    """
    Calculates class weights inversely proportional to class frequencies.
    """
    total_samples = sum(class_counts.values())
    num_classes = len(class_counts)
    class_weights = {}

    for class_name, count in class_counts.items():
        class_weights[class_name] = total_samples / (num_classes * count)

    print("Class weights:")
    for class_name, weight in class_weights.items():
        print(f"Class '{class_name}': {weight:.4f}")

    return class_weights

def map_weights_to_generator_indices(class_weights, generator_class_indices):
    """
    Maps class weights (based on class names) to generator indices used during model training.
    """
    index_weights = {}

    for class_name, weight in class_weights.items():
        if class_name in generator_class_indices:
            index = generator_class_indices[class_name]
            index_weights[index] = weight
        else:
            print(f"Warning: Class '{class_name}' not found in generator indices")

    for class_name, index in generator_class_indices.items():
        if index not in index_weights:
            print(f"Warning: No weight assigned for generator class '{class_name}' (index {index})")

    return index_weights

# %%
# Step 1: Get counts directly from folders
class_counts = get_class_counts_from_folders(train_data_path)

# Step 2: Compute weights
class_weights = calculate_class_weights(class_counts)

# Step 3: Get generator class indices
generator_class_indices = train_gen.class_indices
print("Generator class indices:", generator_class_indices)

# Step 4: Map weights to generator indices
index_weights = map_weights_to_generator_indices(class_weights, generator_class_indices)

print("-" * 30)

# Final weights to use in model.fit()
print("Mapped index weights:")
for idx, weight in sorted(index_weights.items()):
    print(f"Index {idx}: {weight:.4f}")
# Out:
# Class weights:
# Class 'ADT45': 0.2342
# Class 'AndraPonni': 1.5709
# Class 'AtchayaPonni': 1.5709
# Class 'IR20': 1.5709
# Class 'KarnatakaPonni': 1.5709
# Class 'Onthanel': 1.5709
# Class 'Ponni': 1.5709
# Class 'RR': 1.5709
# Class 'Surya': 1.5709
# Class 'Zonal': 1.5709
# Generator class indices: {'ADT45': 0, 'AndraPonni': 1, 'AtchayaPonni': 2, 'IR20': 3, 'KarnatakaPonni': 4, 'Onthanel': 5, 'Ponni': 6, 'RR': 7, 'Surya': 8, 'Zonal': 9}
# ------------------------------
# Mapped index weights:
# Index 0: 0.2342
# Index 1: 1.5709
# Index 2: 1.5709
# Index 3: 1.5709
# Index 4: 1.5709
# Index 5: 1.5709
# Index 6: 1.5709
# Index 7: 1.5709
# Index 8: 1.5709
# Index 9: 1.5709

# %% [markdown]
# ## Callback functions for training monitoring and improvement

# %%
# Callbacks for monitoring NaN Values
class TerminateNaN(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        loss = logs.get('loss')
        if loss is not None:
            if np.isnan(loss) or np.isinf(loss):
                print(f"Invalid loss and terminated at loss {loss}; epoch: {epoch}")
                self.model.stop_training = True

terminate_nan = TerminateNaN()

# Callbacks for checking loss spike
class LossSpikeStopper(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_loss = logs.get('val_loss')
        if val_loss is not None and val_loss > 5.0 and epoch > 10:
            print(f"\n[Early Stop] Validation loss spiked to {val_loss:.4f} at epoch {epoch}.")
            self.model.stop_training = True

loss_spike_stopper = LossSpikeStopper()

# %%
# Save model after every epoch if the validation accuracy improves from previous epoch
cnn_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model/task2_cnn_model.h5',
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    save_freq='epoch'
)

# %%
efficient_net_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model/task2_efficient_net_model.h5',
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    save_freq='epoch'
)

# %%
resnet50_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_model/task2_resnet50_model.h5',
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    save_freq='epoch'
)

# %%
# Standard learning rate reduction on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.5,
    patience=3,
    verbose=1,
    mode="auto",
    min_delta=0.001,
    cooldown=1,
    min_lr=1e-6
)

# Early stopping to prevent overfitting (validation loss stops improving)
early_stopping_loss = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# Early stopping if validation accuracy doesn't improve
early_stopping_accuracy = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode='max',
    restore_best_weights=True
)


# CSV logger to save training metrics to file
cnn_csv_logger = tf.keras.callbacks.CSVLogger(
    filename='logs/task2_cnn_training_history.csv',
    separator=',',
    append=True
)

efficient_net_csv_logger = tf.keras.callbacks.CSVLogger(
    filename='logs/task2_efficient_net_training_history.csv',
    separator=',',
    append=True
)

resnet50_csv_logger = tf.keras.callbacks.CSVLogger(
    filename='logs/task2_resnet50_training_history.csv',
    separator=',',
    append=True
)

# Tensorboard test Track metrics, images, and more with TensorBoard:
tensorboard_cb = TensorBoard(log_dir='logs', histogram_freq=1)

# %% [markdown]
# ## Evaluation Model

# %%
def evaluate_model(history):
    plt.figure(figsize=(18, 5))

    # Accuracy plot
    plt.subplot(1, 3, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Precision plot
    plt.subplot(1, 3, 2)
    plt.plot(history.history['precision'], label='Train Precision')
    if 'val_precision' in history.history:
        plt.plot(history.history['val_precision'], label='Val Precision')
    plt.title('Model Precision')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()

    # Loss plot
    plt.subplot(1, 3, 3)
    plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### CNN Model

# %%
# For Task 2: Paddy Variety Identification with in-model augmentation
num_classes = 10
l2_reg = 1e-4  # L2 regularization strength
dropout_rate = 0.3  # You can adjust this (e.g., 0.3 to 0.5)

cnn_model = models.Sequential([
    # Block 1
    layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(l2_reg), input_shape=(224, 224, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(dropout_rate),

    # Block 2
    layers.Conv2D(64, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(l2_reg)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(dropout_rate),

    # Block 3
    layers.Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(l2_reg)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(dropout_rate),

    # Flatten & Dense
    layers.Flatten(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),  # Slightly higher dropout before output

    # Output
    layers.Dense(num_classes, activation='softmax',kernel_regularizer=regularizers.l2(l2_reg))
])

# Compile the model
cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=[tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
             tf.keras.metrics.Precision(name="precision"),
             tf.keras.metrics.Recall(name="recall")]
)

cnn_model.build(input_shape=(None, 224, 224, 3))
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  dropout (Dropout)           (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 128)       0
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 25,788,106
# Trainable params: 25,787,146
# Non-trainable params: 960
# _________________________________________________________________

# %%
cnn_history = cnn_model.fit(
    train_gen,
    batch_size = 16,
    validation_data = valid_gen,
    epochs=150,
    verbose=1,
    class_weight=index_weights,
        callbacks = [
            early_stopping_loss,
            early_stopping_accuracy,
            reduce_lr,
            loss_spike_stopper,
            terminate_nan,
            cnn_checkpoint,
            cnn_csv_logger,
            tensorboard_cb,
        ]
)
# Out:
# Epoch 1/150
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0324s vs `on_train_batch_end` time: 0.0454s). Check your callbacks.
# 406/406 [==============================] - ETA: 0s - loss: 2.1971 - accuracy: 0.3588 - precision: 0.4632 - recall: 0.2040
# Epoch 1: val_accuracy improved from -inf to 0.06728, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 167s 397ms/step - loss: 2.1971 - accuracy: 0.3588 - precision: 0.4632 - recall: 0.2040 - val_loss: 48.8210 - val_accuracy: 0.0673 - val_precision: 0.0673 - val_recall: 0.0673 - lr: 1.0000e-04
# Epoch 2/150
# 406/406 [==============================] - ETA: 0s - loss: 1.6565 - accuracy: 0.4987 - precision: 0.6144 - recall: 0.3449
# Epoch 2: val_accuracy improved from 0.06728 to 0.48302, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 43s 106ms/step - loss: 1.6565 - accuracy: 0.4987 - precision: 0.6144 - recall: 0.3449 - val_loss: 3.0753 - val_accuracy: 0.4830 - val_precision: 0.5002 - val_recall: 0.4309 - lr: 1.0000e-04
# Epoch 3/150
# 406/406 [==============================] - ETA: 0s - loss: 1.3645 - accuracy: 0.5917 - precision: 0.7129 - recall: 0.4393
# Epoch 3: val_accuracy improved from 0.48302 to 0.55556, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 45s 109ms/step - loss: 1.3645 - accuracy: 0.5917 - precision: 0.7129 - recall: 0.4393 - val_loss: 2.2822 - val_accuracy: 0.5556 - val_precision: 0.6113 - val_recall: 0.4957 - lr: 1.0000e-04
# Epoch 4/150
# 406/406 [==============================] - ETA: 0s - loss: 1.1660 - accuracy: 0.6713 - precision: 0.7885 - recall: 0.5321
# Epoch 4: val_accuracy improved from 0.55556 to 0.60926, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 45s 109ms/step - loss: 1.1660 - accuracy: 0.6713 - precision: 0.7885 - recall: 0.5321 - val_loss: 1.8900 - val_accuracy: 0.6093 - val_precision: 0.6644 - val_recall: 0.5494 - lr: 1.0000e-04
# Epoch 5/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0146 - accuracy: 0.7277 - precision: 0.8324 - recall: 0.6023
# Epoch 5: val_accuracy did not improve from 0.60926
# 406/406 [==============================] - 45s 111ms/step - loss: 1.0146 - accuracy: 0.7277 - precision: 0.8324 - recall: 0.6023 - val_loss: 2.1077 - val_accuracy: 0.5762 - val_precision: 0.6156 - val_recall: 0.5225 - lr: 1.0000e-04
# Epoch 6/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9109 - accuracy: 0.7832 - precision: 0.8712 - recall: 0.6638
# Epoch 6: val_accuracy did not improve from 0.60926
# 406/406 [==============================] - 44s 108ms/step - loss: 0.9109 - accuracy: 0.7832 - precision: 0.8712 - recall: 0.6638 - val_loss: 2.0290 - val_accuracy: 0.5966 - val_precision: 0.6556 - val_recall: 0.5559 - lr: 1.0000e-04
# Epoch 7/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8153 - accuracy: 0.8214 - precision: 0.8997 - recall: 0.7200
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 7: val_accuracy did not improve from 0.60926
# 406/406 [==============================] - 41s 100ms/step - loss: 0.8153 - accuracy: 0.8214 - precision: 0.8997 - recall: 0.7200 - val_loss: 2.5143 - val_accuracy: 0.6000 - val_precision: 0.6622 - val_recall: 0.5438 - lr: 1.0000e-04
# Epoch 8/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7128 - accuracy: 0.8670 - precision: 0.9274 - recall: 0.7838
# Epoch 8: val_accuracy improved from 0.60926 to 0.61204, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.7128 - accuracy: 0.8670 - precision: 0.9274 - recall: 0.7838 - val_loss: 2.3119 - val_accuracy: 0.6120 - val_precision: 0.6723 - val_recall: 0.5738 - lr: 5.0000e-05
# Epoch 9/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.8803 - precision: 0.9365 - recall: 0.8096
# Epoch 9: val_accuracy improved from 0.61204 to 0.64877, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 42s 102ms/step - loss: 0.6827 - accuracy: 0.8803 - precision: 0.9365 - recall: 0.8096 - val_loss: 2.0261 - val_accuracy: 0.6488 - val_precision: 0.7035 - val_recall: 0.6108 - lr: 5.0000e-05
# Epoch 10/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.8960 - precision: 0.9448 - recall: 0.8288
# Epoch 10: val_accuracy did not improve from 0.64877
# 406/406 [==============================] - 41s 100ms/step - loss: 0.6553 - accuracy: 0.8960 - precision: 0.9448 - recall: 0.8288 - val_loss: 2.0381 - val_accuracy: 0.6333 - val_precision: 0.6914 - val_recall: 0.5815 - lr: 5.0000e-05
# Epoch 11/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.9058 - precision: 0.9496 - recall: 0.8457
# Epoch 11: val_accuracy did not improve from 0.64877
# 406/406 [==============================] - 41s 100ms/step - loss: 0.6334 - accuracy: 0.9058 - precision: 0.9496 - recall: 0.8457 - val_loss: 1.7605 - val_accuracy: 0.6417 - val_precision: 0.6999 - val_recall: 0.6003 - lr: 5.0000e-05
# Epoch 12/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6172 - accuracy: 0.9166 - precision: 0.9529 - recall: 0.8535
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 12: val_accuracy did not improve from 0.64877
# 406/406 [==============================] - 41s 101ms/step - loss: 0.6172 - accuracy: 0.9166 - precision: 0.9529 - recall: 0.8535 - val_loss: 2.0432 - val_accuracy: 0.6151 - val_precision: 0.6729 - val_recall: 0.5784 - lr: 5.0000e-05
# Epoch 13/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.9247 - precision: 0.9599 - recall: 0.8785
# Epoch 13: val_accuracy improved from 0.64877 to 0.67191, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 42s 102ms/step - loss: 0.5876 - accuracy: 0.9247 - precision: 0.9599 - recall: 0.8785 - val_loss: 1.7078 - val_accuracy: 0.6719 - val_precision: 0.7306 - val_recall: 0.6244 - lr: 2.5000e-05
# Epoch 14/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5691 - accuracy: 0.9352 - precision: 0.9660 - recall: 0.8912
# Epoch 14: val_accuracy improved from 0.67191 to 0.67963, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5691 - accuracy: 0.9352 - precision: 0.9660 - recall: 0.8912 - val_loss: 1.6036 - val_accuracy: 0.6796 - val_precision: 0.7403 - val_recall: 0.6370 - lr: 2.5000e-05
# Epoch 15/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5667 - accuracy: 0.9361 - precision: 0.9672 - recall: 0.8974
# Epoch 15: val_accuracy did not improve from 0.67963
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5667 - accuracy: 0.9361 - precision: 0.9672 - recall: 0.8974 - val_loss: 1.8165 - val_accuracy: 0.6778 - val_precision: 0.7351 - val_recall: 0.6380 - lr: 2.5000e-05
# Epoch 16/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5470 - accuracy: 0.9462 - precision: 0.9706 - recall: 0.9069
# Epoch 16: val_accuracy did not improve from 0.67963
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5470 - accuracy: 0.9462 - precision: 0.9706 - recall: 0.9069 - val_loss: 1.7187 - val_accuracy: 0.6719 - val_precision: 0.7323 - val_recall: 0.6272 - lr: 2.5000e-05
# Epoch 17/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5437 - accuracy: 0.9506 - precision: 0.9744 - recall: 0.9146
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 17: val_accuracy did not improve from 0.67963
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5437 - accuracy: 0.9506 - precision: 0.9744 - recall: 0.9146 - val_loss: 1.5514 - val_accuracy: 0.6728 - val_precision: 0.7370 - val_recall: 0.6235 - lr: 2.5000e-05
# Epoch 18/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5364 - accuracy: 0.9512 - precision: 0.9735 - recall: 0.9170
# Epoch 18: val_accuracy improved from 0.67963 to 0.68673, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5364 - accuracy: 0.9512 - precision: 0.9735 - recall: 0.9170 - val_loss: 1.5665 - val_accuracy: 0.6867 - val_precision: 0.7421 - val_recall: 0.6386 - lr: 1.2500e-05
# Epoch 19/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5339 - accuracy: 0.9566 - precision: 0.9777 - recall: 0.9242
# Epoch 19: val_accuracy improved from 0.68673 to 0.69907, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5339 - accuracy: 0.9566 - precision: 0.9777 - recall: 0.9242 - val_loss: 1.5216 - val_accuracy: 0.6991 - val_precision: 0.7496 - val_recall: 0.6457 - lr: 1.2500e-05
# Epoch 20/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5233 - accuracy: 0.9581 - precision: 0.9787 - recall: 0.9267
# Epoch 20: val_accuracy improved from 0.69907 to 0.70247, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5233 - accuracy: 0.9581 - precision: 0.9787 - recall: 0.9267 - val_loss: 1.4947 - val_accuracy: 0.7025 - val_precision: 0.7526 - val_recall: 0.6543 - lr: 1.2500e-05
# Epoch 21/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.9580 - precision: 0.9769 - recall: 0.9305
# Epoch 21: val_accuracy did not improve from 0.70247
# 406/406 [==============================] - 41s 100ms/step - loss: 0.5220 - accuracy: 0.9580 - precision: 0.9769 - recall: 0.9305 - val_loss: 1.5699 - val_accuracy: 0.6886 - val_precision: 0.7342 - val_recall: 0.6377 - lr: 1.2500e-05
# Epoch 22/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5172 - accuracy: 0.9610 - precision: 0.9798 - recall: 0.9319
# Epoch 22: val_accuracy improved from 0.70247 to 0.71080, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5172 - accuracy: 0.9610 - precision: 0.9798 - recall: 0.9319 - val_loss: 1.4683 - val_accuracy: 0.7108 - val_precision: 0.7622 - val_recall: 0.6688 - lr: 1.2500e-05
# Epoch 23/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.9633 - precision: 0.9823 - recall: 0.9358
# Epoch 23: val_accuracy did not improve from 0.71080
# 406/406 [==============================] - 41s 100ms/step - loss: 0.5130 - accuracy: 0.9633 - precision: 0.9823 - recall: 0.9358 - val_loss: 1.4634 - val_accuracy: 0.7046 - val_precision: 0.7547 - val_recall: 0.6608 - lr: 1.2500e-05
# Epoch 24/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5154 - accuracy: 0.9649 - precision: 0.9816 - recall: 0.9351
# Epoch 24: val_accuracy improved from 0.71080 to 0.71327, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 41s 101ms/step - loss: 0.5154 - accuracy: 0.9649 - precision: 0.9816 - recall: 0.9351 - val_loss: 1.4453 - val_accuracy: 0.7133 - val_precision: 0.7588 - val_recall: 0.6719 - lr: 1.2500e-05
# Epoch 25/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.9693 - precision: 0.9846 - recall: 0.9410
# Epoch 25: val_accuracy did not improve from 0.71327
# 406/406 [==============================] - 41s 100ms/step - loss: 0.5026 - accuracy: 0.9693 - precision: 0.9846 - recall: 0.9410 - val_loss: 1.9975 - val_accuracy: 0.6250 - val_precision: 0.6718 - val_recall: 0.5769 - lr: 1.2500e-05
# Epoch 26/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.9672 - precision: 0.9822 - recall: 0.9409
# Epoch 26: val_accuracy did not improve from 0.71327
# 406/406 [==============================] - 41s 100ms/step - loss: 0.5025 - accuracy: 0.9672 - precision: 0.9822 - recall: 0.9409 - val_loss: 2.0026 - val_accuracy: 0.6244 - val_precision: 0.6654 - val_recall: 0.5830 - lr: 1.2500e-05
# Epoch 27/150
# 406/406 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.9687 - precision: 0.9837 - recall: 0.9429
# Epoch 27: val_accuracy improved from 0.71327 to 0.72006, saving model to saved_model\task2_cnn_model.h5
# 406/406 [==============================] - 42s 102ms/step - loss: 0.5022 - accuracy: 0.9687 - precision: 0.9837 - recall: 0.9429 - val_loss: 1.4165 - val_accuracy: 0.7201 - val_precision: 0.7595 - val_recall: 0.6775 - lr: 1.2500e-05
# Epoch 28/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.9695 - precision: 0.9850 - recall: 0.9436
# Epoch 28: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4973 - accuracy: 0.9695 - precision: 0.9850 - recall: 0.9436 - val_loss: 2.0516 - val_accuracy: 0.6546 - val_precision: 0.7045 - val_recall: 0.6136 - lr: 1.2500e-05
# Epoch 29/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.9704 - precision: 0.9841 - recall: 0.9474
# Epoch 29: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4947 - accuracy: 0.9704 - precision: 0.9841 - recall: 0.9474 - val_loss: 1.8348 - val_accuracy: 0.6691 - val_precision: 0.7132 - val_recall: 0.6309 - lr: 1.2500e-05
# Epoch 30/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4924 - accuracy: 0.9684 - precision: 0.9828 - recall: 0.9448
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 30: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4924 - accuracy: 0.9684 - precision: 0.9828 - recall: 0.9448 - val_loss: 1.8143 - val_accuracy: 0.6704 - val_precision: 0.7146 - val_recall: 0.6330 - lr: 1.2500e-05
# Epoch 31/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.9717 - precision: 0.9846 - recall: 0.9490
# Epoch 31: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 42s 102ms/step - loss: 0.4866 - accuracy: 0.9717 - precision: 0.9846 - recall: 0.9490 - val_loss: 1.6344 - val_accuracy: 0.6969 - val_precision: 0.7381 - val_recall: 0.6515 - lr: 6.2500e-06
# Epoch 32/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4829 - accuracy: 0.9748 - precision: 0.9867 - recall: 0.9536
# Epoch 32: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4829 - accuracy: 0.9748 - precision: 0.9867 - recall: 0.9536 - val_loss: 1.5521 - val_accuracy: 0.7031 - val_precision: 0.7476 - val_recall: 0.6583 - lr: 6.2500e-06
# Epoch 33/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.9751 - precision: 0.9864 - recall: 0.9529
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 33: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 101ms/step - loss: 0.4803 - accuracy: 0.9751 - precision: 0.9864 - recall: 0.9529 - val_loss: 1.9737 - val_accuracy: 0.6247 - val_precision: 0.6703 - val_recall: 0.5747 - lr: 6.2500e-06
# Epoch 34/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.9751 - precision: 0.9872 - recall: 0.9536
# Epoch 34: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4779 - accuracy: 0.9751 - precision: 0.9872 - recall: 0.9536 - val_loss: 2.0427 - val_accuracy: 0.6160 - val_precision: 0.6603 - val_recall: 0.5657 - lr: 3.1250e-06
# Epoch 35/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.9757 - precision: 0.9866 - recall: 0.9573
# Epoch 35: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4767 - accuracy: 0.9757 - precision: 0.9866 - recall: 0.9573 - val_loss: 1.4869 - val_accuracy: 0.7025 - val_precision: 0.7424 - val_recall: 0.6574 - lr: 3.1250e-06
# Epoch 36/150
# 406/406 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.9757 - precision: 0.9879 - recall: 0.9540
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 36: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4765 - accuracy: 0.9757 - precision: 0.9879 - recall: 0.9540 - val_loss: 1.4750 - val_accuracy: 0.6963 - val_precision: 0.7377 - val_recall: 0.6552 - lr: 3.1250e-06
# Epoch 37/150
# Restoring model weights from the end of the best epoch: 27.0.4764 - accuracy: 0.9759 - precision: 0.9870 - recall: 0.9538
#
# Epoch 37: val_accuracy did not improve from 0.72006
# 406/406 [==============================] - 41s 100ms/step - loss: 0.4764 - accuracy: 0.9759 - precision: 0.9870 - recall: 0.9538 - val_loss: 1.4019 - val_accuracy: 0.7102 - val_precision: 0.7458 - val_recall: 0.6639 - lr: 1.5625e-06
# Epoch 37: early stopping

# %%
cnn_val_acc = evaluate_model(cnn_history)

# %% [markdown]
# ### EfficientNet Model

# %%
from tensorflow.keras import layers, models, regularizers
import tensorflow as tf

# Configuration
input_shape = (224, 224, 3)  # You can also use 300x300 (default for B3)
num_classes = 10
l2_reg = 1e-4

# Load EfficientNetB3 without pretrained weights
base_model = EfficientNetB0(
    include_top=False,
    weights=None,  # Training from scratch
    input_shape=input_shape
)

# Make the base model trainable
base_model.trainable = True

# Custom classification head
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(num_classes, activation='softmax')(x)

# Final model
efficientnet_model = models.Model(inputs=base_model.input, outputs=outputs)

# Compile the model
efficientnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

# Print summary
efficientnet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 96  1536        ['block1a_project_bn[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 112, 112, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 113, 113, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 59, 59, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 28, 28, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 28, 28, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 28, 28, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 28, 28, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 28, 28, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 29, 29, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 14, 14, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 14, 14, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 14, 14, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 14, 14, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 14, 14, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 14, 14, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 14, 14, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 14, 14, 480)  38400       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 14, 14, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 14, 14, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 14, 14, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 14, 14, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 14, 14, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 14, 14, 480)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 14, 14, 112)  53760       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 14, 14, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv (DepthwiseConv2  (None, 14, 14, 672)  16800      ['block5b_expand_activation[0][0]
#  D)                                                              ']
#
#  block5b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5b_dwconv[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 14, 14, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 14, 14, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 14, 14, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 14, 14, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv (DepthwiseConv2  (None, 14, 14, 672)  16800      ['block5c_expand_activation[0][0]
#  D)                                                              ']
#
#  block5c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5c_dwconv[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 14, 14, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 14, 14, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 14, 14, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5c_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 14, 14, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, 17, 17, 672)  0          ['block6a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block6a_dwconv (DepthwiseConv2  (None, 7, 7, 672)   16800       ['block6a_dwconv_pad[0][0]']
#  D)
#
#  block6a_bn (BatchNormalization  (None, 7, 7, 672)   2688        ['block6a_dwconv[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 7, 7, 672)   0           ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 7, 7, 672)    0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 7, 7, 192)    129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6a_project_bn[0][0]']
#
#  block6b_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6b_expand_conv[0][0]']
#  ization)
#
#  block6b_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6b_expand_bn[0][0]']
#  ivation)
#
#  block6b_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6b_expand_activation[0][0]
#  D)                                                              ']
#
#  block6b_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6b_dwconv[0][0]']
#  )
#
#  block6b_activation (Activation  (None, 7, 7, 1152)  0           ['block6b_bn[0][0]']
#  )
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6b_activation[0][0]',
#                                                                   'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6b_se_excite[0][0]']
#
#  block6b_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6b_project_conv[0][0]']
#  lization)
#
#  block6b_drop (Dropout)         (None, 7, 7, 192)    0           ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)              (None, 7, 7, 192)    0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6b_add[0][0]']
#
#  block6c_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6c_expand_conv[0][0]']
#  ization)
#
#  block6c_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6c_expand_bn[0][0]']
#  ivation)
#
#  block6c_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6c_expand_activation[0][0]
#  D)                                                              ']
#
#  block6c_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6c_dwconv[0][0]']
#  )
#
#  block6c_activation (Activation  (None, 7, 7, 1152)  0           ['block6c_bn[0][0]']
#  )
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6c_activation[0][0]',
#                                                                   'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6c_se_excite[0][0]']
#
#  block6c_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6c_project_conv[0][0]']
#  lization)
#
#  block6c_drop (Dropout)         (None, 7, 7, 192)    0           ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)              (None, 7, 7, 192)    0           ['block6c_drop[0][0]',
#                                                                   'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6c_add[0][0]']
#
#  block6d_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6d_expand_conv[0][0]']
#  ization)
#
#  block6d_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6d_expand_bn[0][0]']
#  ivation)
#
#  block6d_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  28800       ['block6d_expand_activation[0][0]
#  D)                                                              ']
#
#  block6d_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6d_dwconv[0][0]']
#  )
#
#  block6d_activation (Activation  (None, 7, 7, 1152)  0           ['block6d_bn[0][0]']
#  )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6d_activation[0][0]',
#                                                                   'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 7, 7, 192)    0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 7, 7, 192)    0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6d_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 7, 7, 1152)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 7, 7, 1152)  10368       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 7, 7, 1152)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 7, 7, 320)    368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 320)   1280        ['block7a_project_conv[0][0]']
#  lization)
#
#  top_conv (Conv2D)              (None, 7, 7, 1280)   409600      ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1280)   0           ['top_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense_2 (Dense)                (None, 256)          327936      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization_4 (BatchNo  (None, 256)         1024        ['dense_2[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 256)          0           ['batch_normalization_4[0][0]']
#
#  dense_3 (Dense)                (None, 128)          32896       ['dropout_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 128)         512         ['dense_3[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 128)          0           ['batch_normalization_5[0][0]']
#
#  dense_4 (Dense)                (None, 10)           1290        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 4,413,229
# Trainable params: 4,370,438
# Non-trainable params: 42,791
# __________________________________________________________________________________________________

# %%
efficient_net_history = efficientnet_model.fit(
    train_gen,
    batch_size = 16,
    validation_data = valid_gen,
    epochs=150,
    verbose=1,
    class_weight=index_weights,
        callbacks = [
            early_stopping_loss,
            early_stopping_accuracy,
            reduce_lr,
            loss_spike_stopper,
            terminate_nan,
            efficient_net_checkpoint,
            efficient_net_csv_logger,
            tensorboard_cb,
        ]
)
# Out:
# Epoch 1/150
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0701s vs `on_train_batch_end` time: 0.1114s). Check your callbacks.
# 406/406 [==============================] - ETA: 0s - loss: 2.9258 - accuracy: 0.1241 - precision: 0.1314 - recall: 0.0221
# Epoch 1: val_accuracy improved from -inf to 0.06358, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 86s 199ms/step - loss: 2.9258 - accuracy: 0.1241 - precision: 0.1314 - recall: 0.0221 - val_loss: 2.5992 - val_accuracy: 0.0636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/150
# 406/406 [==============================] - ETA: 0s - loss: 2.6424 - accuracy: 0.1678 - precision: 0.2198 - recall: 0.0332
# Epoch 2: val_accuracy improved from 0.06358 to 0.17840, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 2.6424 - accuracy: 0.1678 - precision: 0.2198 - recall: 0.0332 - val_loss: 2.3074 - val_accuracy: 0.1784 - val_precision: 0.3276 - val_recall: 0.0296 - lr: 1.0000e-04
# Epoch 3/150
# 406/406 [==============================] - ETA: 0s - loss: 2.4699 - accuracy: 0.2185 - precision: 0.2792 - recall: 0.0470
# Epoch 3: val_accuracy improved from 0.17840 to 0.37994, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 2.4699 - accuracy: 0.2185 - precision: 0.2792 - recall: 0.0470 - val_loss: 2.0356 - val_accuracy: 0.3799 - val_precision: 0.5089 - val_recall: 0.0528 - lr: 1.0000e-04
# Epoch 4/150
# 406/406 [==============================] - ETA: 0s - loss: 2.3471 - accuracy: 0.2484 - precision: 0.3238 - recall: 0.0590
# Epoch 4: val_accuracy improved from 0.37994 to 0.40340, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 2.3471 - accuracy: 0.2484 - precision: 0.3238 - recall: 0.0590 - val_loss: 2.0670 - val_accuracy: 0.4034 - val_precision: 0.5574 - val_recall: 0.0630 - lr: 1.0000e-04
# Epoch 5/150
# 406/406 [==============================] - ETA: 0s - loss: 2.2374 - accuracy: 0.2891 - precision: 0.4066 - recall: 0.0883
# Epoch 5: val_accuracy improved from 0.40340 to 0.42469, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 2.2374 - accuracy: 0.2891 - precision: 0.4066 - recall: 0.0883 - val_loss: 1.8937 - val_accuracy: 0.4247 - val_precision: 0.6352 - val_recall: 0.1080 - lr: 1.0000e-04
# Epoch 6/150
# 406/406 [==============================] - ETA: 0s - loss: 2.1426 - accuracy: 0.3158 - precision: 0.4328 - recall: 0.1029
# Epoch 6: val_accuracy did not improve from 0.42469
# 406/406 [==============================] - 79s 195ms/step - loss: 2.1426 - accuracy: 0.3158 - precision: 0.4328 - recall: 0.1029 - val_loss: 1.9073 - val_accuracy: 0.4219 - val_precision: 0.5908 - val_recall: 0.1275 - lr: 1.0000e-04
# Epoch 7/150
# 406/406 [==============================] - ETA: 0s - loss: 2.0489 - accuracy: 0.3383 - precision: 0.4695 - recall: 0.1249
# Epoch 7: val_accuracy improved from 0.42469 to 0.43426, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 2.0489 - accuracy: 0.3383 - precision: 0.4695 - recall: 0.1249 - val_loss: 1.8738 - val_accuracy: 0.4343 - val_precision: 0.5816 - val_recall: 0.2167 - lr: 1.0000e-04
# Epoch 8/150
# 406/406 [==============================] - ETA: 0s - loss: 1.9342 - accuracy: 0.3704 - precision: 0.5277 - recall: 0.1564
# Epoch 8: val_accuracy improved from 0.43426 to 0.44907, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.9342 - accuracy: 0.3704 - precision: 0.5277 - recall: 0.1564 - val_loss: 1.8843 - val_accuracy: 0.4491 - val_precision: 0.5991 - val_recall: 0.2136 - lr: 1.0000e-04
# Epoch 9/150
# 406/406 [==============================] - ETA: 0s - loss: 1.8648 - accuracy: 0.3986 - precision: 0.5702 - recall: 0.1866
# Epoch 9: val_accuracy improved from 0.44907 to 0.51173, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 1.8648 - accuracy: 0.3986 - precision: 0.5702 - recall: 0.1866 - val_loss: 1.6649 - val_accuracy: 0.5117 - val_precision: 0.6674 - val_recall: 0.2818 - lr: 1.0000e-04
# Epoch 10/150
# 406/406 [==============================] - ETA: 0s - loss: 1.7717 - accuracy: 0.4332 - precision: 0.5942 - recall: 0.2163
# Epoch 10: val_accuracy improved from 0.51173 to 0.52130, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 196ms/step - loss: 1.7717 - accuracy: 0.4332 - precision: 0.5942 - recall: 0.2163 - val_loss: 1.7859 - val_accuracy: 0.5213 - val_precision: 0.6621 - val_recall: 0.3278 - lr: 1.0000e-04
# Epoch 11/150
# 406/406 [==============================] - ETA: 0s - loss: 1.6860 - accuracy: 0.4622 - precision: 0.6231 - recall: 0.2549
# Epoch 11: val_accuracy improved from 0.52130 to 0.52593, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 1.6860 - accuracy: 0.4622 - precision: 0.6231 - recall: 0.2549 - val_loss: 1.7860 - val_accuracy: 0.5259 - val_precision: 0.6340 - val_recall: 0.3599 - lr: 1.0000e-04
# Epoch 12/150
# 406/406 [==============================] - ETA: 0s - loss: 1.6020 - accuracy: 0.4978 - precision: 0.6510 - recall: 0.2991
# Epoch 12: val_accuracy improved from 0.52593 to 0.57438, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 1.6020 - accuracy: 0.4978 - precision: 0.6510 - recall: 0.2991 - val_loss: 1.6205 - val_accuracy: 0.5744 - val_precision: 0.7187 - val_recall: 0.3981 - lr: 1.0000e-04
# Epoch 13/150
# 406/406 [==============================] - ETA: 0s - loss: 1.5089 - accuracy: 0.5371 - precision: 0.6921 - recall: 0.3477
# Epoch 13: val_accuracy did not improve from 0.57438
# 406/406 [==============================] - 79s 195ms/step - loss: 1.5089 - accuracy: 0.5371 - precision: 0.6921 - recall: 0.3477 - val_loss: 1.6673 - val_accuracy: 0.5485 - val_precision: 0.6495 - val_recall: 0.4123 - lr: 1.0000e-04
# Epoch 14/150
# 406/406 [==============================] - ETA: 0s - loss: 1.4320 - accuracy: 0.5653 - precision: 0.7095 - recall: 0.3867
# Epoch 14: val_accuracy improved from 0.57438 to 0.59198, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.4320 - accuracy: 0.5653 - precision: 0.7095 - recall: 0.3867 - val_loss: 1.5058 - val_accuracy: 0.5920 - val_precision: 0.7427 - val_recall: 0.4330 - lr: 1.0000e-04
# Epoch 15/150
# 406/406 [==============================] - ETA: 0s - loss: 1.3456 - accuracy: 0.5981 - precision: 0.7333 - recall: 0.4285
# Epoch 15: val_accuracy did not improve from 0.59198
# 406/406 [==============================] - 79s 194ms/step - loss: 1.3456 - accuracy: 0.5981 - precision: 0.7333 - recall: 0.4285 - val_loss: 1.5251 - val_accuracy: 0.5917 - val_precision: 0.6952 - val_recall: 0.4716 - lr: 1.0000e-04
# Epoch 16/150
# 406/406 [==============================] - ETA: 0s - loss: 1.2920 - accuracy: 0.6273 - precision: 0.7532 - recall: 0.4663
# Epoch 16: val_accuracy improved from 0.59198 to 0.59660, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.2920 - accuracy: 0.6273 - precision: 0.7532 - recall: 0.4663 - val_loss: 1.5350 - val_accuracy: 0.5966 - val_precision: 0.6832 - val_recall: 0.4772 - lr: 1.0000e-04
# Epoch 17/150
# 406/406 [==============================] - ETA: 0s - loss: 1.2139 - accuracy: 0.6644 - precision: 0.7885 - recall: 0.5225
# Epoch 17: val_accuracy did not improve from 0.59660
# 406/406 [==============================] - 79s 194ms/step - loss: 1.2139 - accuracy: 0.6644 - precision: 0.7885 - recall: 0.5225 - val_loss: 1.6562 - val_accuracy: 0.5827 - val_precision: 0.6587 - val_recall: 0.5046 - lr: 1.0000e-04
# Epoch 18/150
# 406/406 [==============================] - ETA: 0s - loss: 1.1641 - accuracy: 0.6856 - precision: 0.7921 - recall: 0.5452
# Epoch 18: val_accuracy improved from 0.59660 to 0.61728, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 1.1641 - accuracy: 0.6856 - precision: 0.7921 - recall: 0.5452 - val_loss: 1.5815 - val_accuracy: 0.6173 - val_precision: 0.6878 - val_recall: 0.5392 - lr: 1.0000e-04
# Epoch 19/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0977 - accuracy: 0.7134 - precision: 0.8176 - recall: 0.5921
# Epoch 19: val_accuracy improved from 0.61728 to 0.62438, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.0977 - accuracy: 0.7134 - precision: 0.8176 - recall: 0.5921 - val_loss: 1.5066 - val_accuracy: 0.6244 - val_precision: 0.7056 - val_recall: 0.5451 - lr: 1.0000e-04
# Epoch 20/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0583 - accuracy: 0.7365 - precision: 0.8322 - recall: 0.6201
# Epoch 20: val_accuracy improved from 0.62438 to 0.63148, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.0583 - accuracy: 0.7365 - precision: 0.8322 - recall: 0.6201 - val_loss: 1.4561 - val_accuracy: 0.6315 - val_precision: 0.7008 - val_recall: 0.5472 - lr: 1.0000e-04
# Epoch 21/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0243 - accuracy: 0.7601 - precision: 0.8468 - recall: 0.6542
# Epoch 21: val_accuracy improved from 0.63148 to 0.67315, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 1.0243 - accuracy: 0.7601 - precision: 0.8468 - recall: 0.6542 - val_loss: 1.3713 - val_accuracy: 0.6731 - val_precision: 0.7414 - val_recall: 0.6071 - lr: 1.0000e-04
# Epoch 22/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9893 - accuracy: 0.7752 - precision: 0.8591 - recall: 0.6734
# Epoch 22: val_accuracy improved from 0.67315 to 0.67901, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 0.9893 - accuracy: 0.7752 - precision: 0.8591 - recall: 0.6734 - val_loss: 1.3393 - val_accuracy: 0.6790 - val_precision: 0.7472 - val_recall: 0.5929 - lr: 1.0000e-04
# Epoch 23/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9599 - accuracy: 0.7954 - precision: 0.8727 - recall: 0.6994
# Epoch 23: val_accuracy did not improve from 0.67901
# 406/406 [==============================] - 79s 195ms/step - loss: 0.9599 - accuracy: 0.7954 - precision: 0.8727 - recall: 0.6994 - val_loss: 1.4576 - val_accuracy: 0.6309 - val_precision: 0.7049 - val_recall: 0.5500 - lr: 1.0000e-04
# Epoch 24/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9443 - accuracy: 0.8043 - precision: 0.8764 - recall: 0.7146
# Epoch 24: val_accuracy did not improve from 0.67901
# 406/406 [==============================] - 79s 195ms/step - loss: 0.9443 - accuracy: 0.8043 - precision: 0.8764 - recall: 0.7146 - val_loss: 1.3388 - val_accuracy: 0.6716 - val_precision: 0.7300 - val_recall: 0.6108 - lr: 1.0000e-04
# Epoch 25/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9088 - accuracy: 0.8186 - precision: 0.8876 - recall: 0.7373
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 25: val_accuracy did not improve from 0.67901
# 406/406 [==============================] - 79s 195ms/step - loss: 0.9088 - accuracy: 0.8186 - precision: 0.8876 - recall: 0.7373 - val_loss: 1.5396 - val_accuracy: 0.6086 - val_precision: 0.6664 - val_recall: 0.5438 - lr: 1.0000e-04
# Epoch 26/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8580 - accuracy: 0.8442 - precision: 0.9082 - recall: 0.7681
# Epoch 26: val_accuracy improved from 0.67901 to 0.68796, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 0.8580 - accuracy: 0.8442 - precision: 0.9082 - recall: 0.7681 - val_loss: 1.3263 - val_accuracy: 0.6880 - val_precision: 0.7442 - val_recall: 0.6284 - lr: 5.0000e-05
# Epoch 27/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8442 - accuracy: 0.8596 - precision: 0.9174 - recall: 0.7867
# Epoch 27: val_accuracy improved from 0.68796 to 0.70154, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 0.8442 - accuracy: 0.8596 - precision: 0.9174 - recall: 0.7867 - val_loss: 1.2880 - val_accuracy: 0.7015 - val_precision: 0.7646 - val_recall: 0.6426 - lr: 5.0000e-05
# Epoch 28/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8209 - accuracy: 0.8673 - precision: 0.9213 - recall: 0.7995
# Epoch 28: val_accuracy improved from 0.70154 to 0.71512, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 0.8209 - accuracy: 0.8673 - precision: 0.9213 - recall: 0.7995 - val_loss: 1.2741 - val_accuracy: 0.7151 - val_precision: 0.7695 - val_recall: 0.6491 - lr: 5.0000e-05
# Epoch 29/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8243 - accuracy: 0.8694 - precision: 0.9209 - recall: 0.8016
# Epoch 29: val_accuracy did not improve from 0.71512
# 406/406 [==============================] - 79s 194ms/step - loss: 0.8243 - accuracy: 0.8694 - precision: 0.9209 - recall: 0.8016 - val_loss: 1.2709 - val_accuracy: 0.7148 - val_precision: 0.7614 - val_recall: 0.6716 - lr: 5.0000e-05
# Epoch 30/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8161 - accuracy: 0.8740 - precision: 0.9245 - recall: 0.8063
# Epoch 30: val_accuracy improved from 0.71512 to 0.71667, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 194ms/step - loss: 0.8161 - accuracy: 0.8740 - precision: 0.9245 - recall: 0.8063 - val_loss: 1.2740 - val_accuracy: 0.7167 - val_precision: 0.7661 - val_recall: 0.6593 - lr: 5.0000e-05
# Epoch 31/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8062 - accuracy: 0.8759 - precision: 0.9261 - recall: 0.8167
# Epoch 31: val_accuracy improved from 0.71667 to 0.74198, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 0.8062 - accuracy: 0.8759 - precision: 0.9261 - recall: 0.8167 - val_loss: 1.1915 - val_accuracy: 0.7420 - val_precision: 0.7909 - val_recall: 0.6901 - lr: 5.0000e-05
# Epoch 32/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7946 - accuracy: 0.8827 - precision: 0.9316 - recall: 0.8241
# Epoch 32: val_accuracy did not improve from 0.74198
# 406/406 [==============================] - 78s 193ms/step - loss: 0.7946 - accuracy: 0.8827 - precision: 0.9316 - recall: 0.8241 - val_loss: 1.2663 - val_accuracy: 0.7191 - val_precision: 0.7666 - val_recall: 0.6682 - lr: 5.0000e-05
# Epoch 33/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7946 - accuracy: 0.8829 - precision: 0.9304 - recall: 0.8242
# Epoch 33: val_accuracy did not improve from 0.74198
# 406/406 [==============================] - 78s 193ms/step - loss: 0.7946 - accuracy: 0.8829 - precision: 0.9304 - recall: 0.8242 - val_loss: 1.2689 - val_accuracy: 0.7287 - val_precision: 0.7643 - val_recall: 0.6815 - lr: 5.0000e-05
# Epoch 34/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7921 - accuracy: 0.8886 - precision: 0.9332 - recall: 0.8325
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 34: val_accuracy did not improve from 0.74198
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7921 - accuracy: 0.8886 - precision: 0.9332 - recall: 0.8325 - val_loss: 1.3030 - val_accuracy: 0.7148 - val_precision: 0.7548 - val_recall: 0.6583 - lr: 5.0000e-05
# Epoch 35/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7657 - accuracy: 0.8988 - precision: 0.9426 - recall: 0.8464
# Epoch 35: val_accuracy did not improve from 0.74198
# 406/406 [==============================] - 79s 193ms/step - loss: 0.7657 - accuracy: 0.8988 - precision: 0.9426 - recall: 0.8464 - val_loss: 1.2027 - val_accuracy: 0.7361 - val_precision: 0.7853 - val_recall: 0.6830 - lr: 2.5000e-05
# Epoch 36/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7502 - accuracy: 0.9080 - precision: 0.9471 - recall: 0.8611
# Epoch 36: val_accuracy improved from 0.74198 to 0.74290, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 197ms/step - loss: 0.7502 - accuracy: 0.9080 - precision: 0.9471 - recall: 0.8611 - val_loss: 1.1938 - val_accuracy: 0.7429 - val_precision: 0.7899 - val_recall: 0.6926 - lr: 2.5000e-05
# Epoch 37/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7490 - accuracy: 0.9074 - precision: 0.9459 - recall: 0.8592
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 37: val_accuracy did not improve from 0.74290
# 406/406 [==============================] - 79s 195ms/step - loss: 0.7490 - accuracy: 0.9074 - precision: 0.9459 - recall: 0.8592 - val_loss: 1.2011 - val_accuracy: 0.7426 - val_precision: 0.7839 - val_recall: 0.6864 - lr: 2.5000e-05
# Epoch 38/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7396 - accuracy: 0.9138 - precision: 0.9516 - recall: 0.8696
# Epoch 38: val_accuracy improved from 0.74290 to 0.75000, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 80s 196ms/step - loss: 0.7396 - accuracy: 0.9138 - precision: 0.9516 - recall: 0.8696 - val_loss: 1.1907 - val_accuracy: 0.7500 - val_precision: 0.7890 - val_recall: 0.7086 - lr: 1.2500e-05
# Epoch 39/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7354 - accuracy: 0.9169 - precision: 0.9554 - recall: 0.8700
# Epoch 39: val_accuracy improved from 0.75000 to 0.75185, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7354 - accuracy: 0.9169 - precision: 0.9554 - recall: 0.8700 - val_loss: 1.1718 - val_accuracy: 0.7519 - val_precision: 0.7976 - val_recall: 0.7052 - lr: 1.2500e-05
# Epoch 40/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7311 - accuracy: 0.9181 - precision: 0.9531 - recall: 0.8722
# Epoch 40: val_accuracy did not improve from 0.75185
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7311 - accuracy: 0.9181 - precision: 0.9531 - recall: 0.8722 - val_loss: 1.1796 - val_accuracy: 0.7512 - val_precision: 0.7919 - val_recall: 0.7034 - lr: 1.2500e-05
# Epoch 41/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7277 - accuracy: 0.9163 - precision: 0.9540 - recall: 0.8753
# Epoch 41: val_accuracy improved from 0.75185 to 0.75926, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 0.7277 - accuracy: 0.9163 - precision: 0.9540 - recall: 0.8753 - val_loss: 1.1606 - val_accuracy: 0.7593 - val_precision: 0.7999 - val_recall: 0.7130 - lr: 1.2500e-05
# Epoch 42/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7185 - accuracy: 0.9218 - precision: 0.9556 - recall: 0.8790
# Epoch 42: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 78s 193ms/step - loss: 0.7185 - accuracy: 0.9218 - precision: 0.9556 - recall: 0.8790 - val_loss: 1.1955 - val_accuracy: 0.7506 - val_precision: 0.7864 - val_recall: 0.7046 - lr: 1.2500e-05
# Epoch 43/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7268 - accuracy: 0.9191 - precision: 0.9544 - recall: 0.8760
# Epoch 43: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7268 - accuracy: 0.9191 - precision: 0.9544 - recall: 0.8760 - val_loss: 1.1807 - val_accuracy: 0.7475 - val_precision: 0.7892 - val_recall: 0.7037 - lr: 1.2500e-05
# Epoch 44/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.9255 - precision: 0.9598 - recall: 0.8811
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 44: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 193ms/step - loss: 0.7206 - accuracy: 0.9255 - precision: 0.9598 - recall: 0.8811 - val_loss: 1.1770 - val_accuracy: 0.7528 - val_precision: 0.7921 - val_recall: 0.7090 - lr: 1.2500e-05
# Epoch 45/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.9227 - precision: 0.9555 - recall: 0.8819
# Epoch 45: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 78s 193ms/step - loss: 0.7211 - accuracy: 0.9227 - precision: 0.9555 - recall: 0.8819 - val_loss: 1.1745 - val_accuracy: 0.7503 - val_precision: 0.7938 - val_recall: 0.7000 - lr: 6.2500e-06
# Epoch 46/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7175 - accuracy: 0.9203 - precision: 0.9556 - recall: 0.8784
# Epoch 46: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7175 - accuracy: 0.9203 - precision: 0.9556 - recall: 0.8784 - val_loss: 1.1715 - val_accuracy: 0.7540 - val_precision: 0.7914 - val_recall: 0.7037 - lr: 6.2500e-06
# Epoch 47/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7148 - accuracy: 0.9274 - precision: 0.9584 - recall: 0.8869
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 47: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 195ms/step - loss: 0.7148 - accuracy: 0.9274 - precision: 0.9584 - recall: 0.8869 - val_loss: 1.1696 - val_accuracy: 0.7543 - val_precision: 0.7931 - val_recall: 0.7049 - lr: 6.2500e-06
# Epoch 48/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.9238 - precision: 0.9574 - recall: 0.8852
# Epoch 48: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7181 - accuracy: 0.9238 - precision: 0.9574 - recall: 0.8852 - val_loss: 1.1637 - val_accuracy: 0.7577 - val_precision: 0.7973 - val_recall: 0.7173 - lr: 3.1250e-06
# Epoch 49/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7143 - accuracy: 0.9228 - precision: 0.9556 - recall: 0.8833
# Epoch 49: val_accuracy did not improve from 0.75926
# 406/406 [==============================] - 79s 194ms/step - loss: 0.7143 - accuracy: 0.9228 - precision: 0.9556 - recall: 0.8833 - val_loss: 1.1711 - val_accuracy: 0.7562 - val_precision: 0.7952 - val_recall: 0.7105 - lr: 3.1250e-06
# Epoch 50/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.9262 - precision: 0.9571 - recall: 0.8857
# Epoch 50: val_accuracy improved from 0.75926 to 0.76512, saving model to saved_model\task2_efficient_net_model.h5
# 406/406 [==============================] - 79s 195ms/step - loss: 0.7156 - accuracy: 0.9262 - precision: 0.9571 - recall: 0.8857 - val_loss: 1.1626 - val_accuracy: 0.7651 - val_precision: 0.7976 - val_recall: 0.7127 - lr: 3.1250e-06
# Epoch 51/150
# Restoring model weights from the end of the best epoch: 41.0.7136 - accuracy: 0.9288 - precision: 0.9594 - recall: 0.8902
#
# Epoch 51: val_accuracy did not improve from 0.76512
# 406/406 [==============================] - 79s 193ms/step - loss: 0.7136 - accuracy: 0.9288 - precision: 0.9594 - recall: 0.8902 - val_loss: 1.1675 - val_accuracy: 0.7549 - val_precision: 0.7971 - val_recall: 0.7080 - lr: 3.1250e-06
# Epoch 51: early stopping

# %%
efficient_net_val_acc = evaluate_model(efficient_net_history)

# %% [markdown]
# ### ResNet Model

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import Model, layers, Input, regularizers

num_classes = 10
l2_reg = 1e-4

# Base ResNet50 (from scratch)
base_model = ResNet50(weights=None, include_top=False, input_shape=(224, 224, 3))
base_model.trainable = True

# Input Layer
inputs = Input(shape=(224, 224, 3))
x = base_model(inputs)
x = layers.GlobalAveragePooling2D()(x)

# Feature Extractor
features = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(x)
features = layers.BatchNormalization()(features)
features = layers.Dropout(0.5)(features)

# Attention Mechanism
attention_weights = layers.Dense(512, activation='sigmoid', name='attention_weights')(features)
attention_output = layers.Multiply()([features, attention_weights])

# Classification Head
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(attention_output)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

# Output Layer
outputs = layers.Dense(num_classes, activation='softmax')(x)

# Build the Model
resnet50_model = Model(inputs=inputs, outputs=outputs)

# Compile the Model
resnet50_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

# Show Summary
resnet50_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  resnet50 (Functional)          (None, 7, 7, 2048)   23587712    ['input_3[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['resnet50[0][0]']
#  obalAveragePooling2D)
#
#  dense_5 (Dense)                (None, 512)          1049088     ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  batch_normalization_6 (BatchNo  (None, 512)         2048        ['dense_5[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 512)          0           ['batch_normalization_6[0][0]']
#
#  attention_weights (Dense)      (None, 512)          262656      ['dropout_6[0][0]']
#
#  multiply (Multiply)            (None, 512)          0           ['dropout_6[0][0]',
#                                                                   'attention_weights[0][0]']
#
#  dense_6 (Dense)                (None, 256)          131328      ['multiply[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 256)         1024        ['dense_6[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 256)          0           ['batch_normalization_7[0][0]']
#
#  dense_7 (Dense)                (None, 128)          32896       ['dropout_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 128)         512         ['dense_7[0][0]']
#  rmalization)
#
#  dropout_8 (Dropout)            (None, 128)          0           ['batch_normalization_8[0][0]']
#
#  dense_8 (Dense)                (None, 10)           1290        ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 25,068,554
# Trainable params: 25,013,642
# Non-trainable params: 54,912
# __________________________________________________________________________________________________

# %%
resnet50_history = resnet50_model.fit(
    train_gen,
    batch_size=16,
    validation_data=valid_gen,
    epochs=150,
    verbose=1,
    class_weight=index_weights,
    callbacks=[
        early_stopping_loss,
        early_stopping_accuracy,
        reduce_lr,
        loss_spike_stopper,
        terminate_nan,
        resnet50_checkpoint,
        resnet50_csv_logger
    ]
)
# Out:
# Epoch 1/150
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0988s vs `on_train_batch_end` time: 0.1025s). Check your callbacks.
# 406/406 [==============================] - ETA: 0s - loss: 3.0249 - accuracy: 0.1390 - precision: 0.1628 - recall: 0.0436
# Epoch 1: val_accuracy improved from -inf to 0.06728, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 105s 247ms/step - loss: 3.0249 - accuracy: 0.1390 - precision: 0.1628 - recall: 0.0436 - val_loss: 5.1821 - val_accuracy: 0.0673 - val_precision: 0.0635 - val_recall: 0.0630 - lr: 1.0000e-04
# Epoch 2/150
# 406/406 [==============================] - ETA: 0s - loss: 2.6705 - accuracy: 0.2061 - precision: 0.2598 - recall: 0.0732
# Epoch 2: val_accuracy improved from 0.06728 to 0.34444, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 2.6705 - accuracy: 0.2061 - precision: 0.2598 - recall: 0.0732 - val_loss: 2.3770 - val_accuracy: 0.3444 - val_precision: 0.5908 - val_recall: 0.1315 - lr: 1.0000e-04
# Epoch 3/150
# 406/406 [==============================] - ETA: 0s - loss: 2.4108 - accuracy: 0.2601 - precision: 0.3783 - recall: 0.1099
# Epoch 3: val_accuracy did not improve from 0.34444
# 406/406 [==============================] - 97s 240ms/step - loss: 2.4108 - accuracy: 0.2601 - precision: 0.3783 - recall: 0.1099 - val_loss: 2.7036 - val_accuracy: 0.2364 - val_precision: 0.3906 - val_recall: 0.0821 - lr: 1.0000e-04
# Epoch 4/150
# 406/406 [==============================] - ETA: 0s - loss: 2.2492 - accuracy: 0.3055 - precision: 0.4416 - recall: 0.1454
# Epoch 4: val_accuracy improved from 0.34444 to 0.44012, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 2.2492 - accuracy: 0.3055 - precision: 0.4416 - recall: 0.1454 - val_loss: 2.0206 - val_accuracy: 0.4401 - val_precision: 0.7016 - val_recall: 0.2395 - lr: 1.0000e-04
# Epoch 5/150
# 406/406 [==============================] - ETA: 0s - loss: 2.1027 - accuracy: 0.3289 - precision: 0.4811 - recall: 0.1644
# Epoch 5: val_accuracy did not improve from 0.44012
# 406/406 [==============================] - 97s 239ms/step - loss: 2.1027 - accuracy: 0.3289 - precision: 0.4811 - recall: 0.1644 - val_loss: 2.5470 - val_accuracy: 0.3188 - val_precision: 0.4241 - val_recall: 0.1966 - lr: 1.0000e-04
# Epoch 6/150
# 406/406 [==============================] - ETA: 0s - loss: 1.9772 - accuracy: 0.3668 - precision: 0.5352 - recall: 0.1994
# Epoch 6: val_accuracy improved from 0.44012 to 0.48981, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 1.9772 - accuracy: 0.3668 - precision: 0.5352 - recall: 0.1994 - val_loss: 1.8195 - val_accuracy: 0.4898 - val_precision: 0.7245 - val_recall: 0.3207 - lr: 1.0000e-04
# Epoch 7/150
# 406/406 [==============================] - ETA: 0s - loss: 1.8615 - accuracy: 0.4111 - precision: 0.5786 - recall: 0.2345
# Epoch 7: val_accuracy did not improve from 0.48981
# 406/406 [==============================] - 97s 240ms/step - loss: 1.8615 - accuracy: 0.4111 - precision: 0.5786 - recall: 0.2345 - val_loss: 1.9488 - val_accuracy: 0.4309 - val_precision: 0.6928 - val_recall: 0.2373 - lr: 1.0000e-04
# Epoch 8/150
# 406/406 [==============================] - ETA: 0s - loss: 1.7809 - accuracy: 0.4455 - precision: 0.6254 - recall: 0.2744
# Epoch 8: val_accuracy did not improve from 0.48981
# 406/406 [==============================] - 97s 240ms/step - loss: 1.7809 - accuracy: 0.4455 - precision: 0.6254 - recall: 0.2744 - val_loss: 2.0774 - val_accuracy: 0.4534 - val_precision: 0.5966 - val_recall: 0.3059 - lr: 1.0000e-04
# Epoch 9/150
# 406/406 [==============================] - ETA: 0s - loss: 1.6789 - accuracy: 0.4883 - precision: 0.6520 - recall: 0.3136
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 9: val_accuracy did not improve from 0.48981
# 406/406 [==============================] - 98s 240ms/step - loss: 1.6789 - accuracy: 0.4883 - precision: 0.6520 - recall: 0.3136 - val_loss: 1.9279 - val_accuracy: 0.4694 - val_precision: 0.5478 - val_recall: 0.3219 - lr: 1.0000e-04
# Epoch 10/150
# 406/406 [==============================] - ETA: 0s - loss: 1.5418 - accuracy: 0.5290 - precision: 0.6985 - recall: 0.3604
# Epoch 10: val_accuracy improved from 0.48981 to 0.49537, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 100s 246ms/step - loss: 1.5418 - accuracy: 0.5290 - precision: 0.6985 - recall: 0.3604 - val_loss: 1.7441 - val_accuracy: 0.4954 - val_precision: 0.6850 - val_recall: 0.3497 - lr: 5.0000e-05
# Epoch 11/150
# 406/406 [==============================] - ETA: 0s - loss: 1.4679 - accuracy: 0.5630 - precision: 0.7126 - recall: 0.4026
# Epoch 11: val_accuracy improved from 0.49537 to 0.52654, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 1.4679 - accuracy: 0.5630 - precision: 0.7126 - recall: 0.4026 - val_loss: 1.7179 - val_accuracy: 0.5265 - val_precision: 0.6700 - val_recall: 0.3515 - lr: 5.0000e-05
# Epoch 12/150
# 406/406 [==============================] - ETA: 0s - loss: 1.4063 - accuracy: 0.6013 - precision: 0.7461 - recall: 0.4448
# Epoch 12: val_accuracy improved from 0.52654 to 0.56111, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 1.4063 - accuracy: 0.6013 - precision: 0.7461 - recall: 0.4448 - val_loss: 1.6245 - val_accuracy: 0.5611 - val_precision: 0.7034 - val_recall: 0.4056 - lr: 5.0000e-05
# Epoch 13/150
# 406/406 [==============================] - ETA: 0s - loss: 1.3615 - accuracy: 0.6125 - precision: 0.7411 - recall: 0.4608
# Epoch 13: val_accuracy improved from 0.56111 to 0.64414, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 1.3615 - accuracy: 0.6125 - precision: 0.7411 - recall: 0.4608 - val_loss: 1.4377 - val_accuracy: 0.6441 - val_precision: 0.7681 - val_recall: 0.5120 - lr: 5.0000e-05
# Epoch 14/150
# 406/406 [==============================] - ETA: 0s - loss: 1.3070 - accuracy: 0.6405 - precision: 0.7578 - recall: 0.5001
# Epoch 14: val_accuracy did not improve from 0.64414
# 406/406 [==============================] - 98s 240ms/step - loss: 1.3070 - accuracy: 0.6405 - precision: 0.7578 - recall: 0.5001 - val_loss: 1.5956 - val_accuracy: 0.6336 - val_precision: 0.7054 - val_recall: 0.5410 - lr: 5.0000e-05
# Epoch 15/150
# 406/406 [==============================] - ETA: 0s - loss: 1.2513 - accuracy: 0.6698 - precision: 0.7789 - recall: 0.5305
# Epoch 15: val_accuracy did not improve from 0.64414
# 406/406 [==============================] - 98s 240ms/step - loss: 1.2513 - accuracy: 0.6698 - precision: 0.7789 - recall: 0.5305 - val_loss: 2.0545 - val_accuracy: 0.4969 - val_precision: 0.5727 - val_recall: 0.4231 - lr: 5.0000e-05
# Epoch 16/150
# 406/406 [==============================] - ETA: 0s - loss: 1.2214 - accuracy: 0.6862 - precision: 0.7900 - recall: 0.5660
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_accuracy did not improve from 0.64414
# 406/406 [==============================] - 98s 241ms/step - loss: 1.2214 - accuracy: 0.6862 - precision: 0.7900 - recall: 0.5660 - val_loss: 2.2542 - val_accuracy: 0.4642 - val_precision: 0.5119 - val_recall: 0.4059 - lr: 5.0000e-05
# Epoch 17/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0789 - accuracy: 0.7538 - precision: 0.8465 - recall: 0.6336
# Epoch 17: val_accuracy did not improve from 0.64414
# 406/406 [==============================] - 98s 240ms/step - loss: 1.0789 - accuracy: 0.7538 - precision: 0.8465 - recall: 0.6336 - val_loss: 1.4541 - val_accuracy: 0.6327 - val_precision: 0.7126 - val_recall: 0.5281 - lr: 2.5000e-05
# Epoch 18/150
# 406/406 [==============================] - ETA: 0s - loss: 1.0114 - accuracy: 0.7805 - precision: 0.8616 - recall: 0.6704
# Epoch 18: val_accuracy improved from 0.64414 to 0.73457, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 99s 243ms/step - loss: 1.0114 - accuracy: 0.7805 - precision: 0.8616 - recall: 0.6704 - val_loss: 1.2220 - val_accuracy: 0.7346 - val_precision: 0.8107 - val_recall: 0.6386 - lr: 2.5000e-05
# Epoch 19/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9582 - accuracy: 0.8123 - precision: 0.8844 - recall: 0.7175
# Epoch 19: val_accuracy did not improve from 0.73457
# 406/406 [==============================] - 98s 240ms/step - loss: 0.9582 - accuracy: 0.8123 - precision: 0.8844 - recall: 0.7175 - val_loss: 1.3079 - val_accuracy: 0.7160 - val_precision: 0.7790 - val_recall: 0.6333 - lr: 2.5000e-05
# Epoch 20/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9272 - accuracy: 0.8324 - precision: 0.8911 - recall: 0.7451
# Epoch 20: val_accuracy did not improve from 0.73457
# 406/406 [==============================] - 97s 240ms/step - loss: 0.9272 - accuracy: 0.8324 - precision: 0.8911 - recall: 0.7451 - val_loss: 1.2655 - val_accuracy: 0.7346 - val_precision: 0.8036 - val_recall: 0.6605 - lr: 2.5000e-05
# Epoch 21/150
# 406/406 [==============================] - ETA: 0s - loss: 0.9067 - accuracy: 0.8421 - precision: 0.9006 - recall: 0.7579
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 21: val_accuracy did not improve from 0.73457
# 406/406 [==============================] - 98s 240ms/step - loss: 0.9067 - accuracy: 0.8421 - precision: 0.9006 - recall: 0.7579 - val_loss: 1.2947 - val_accuracy: 0.7198 - val_precision: 0.7859 - val_recall: 0.6414 - lr: 2.5000e-05
# Epoch 22/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8522 - accuracy: 0.8780 - precision: 0.9241 - recall: 0.8029
# Epoch 22: val_accuracy improved from 0.73457 to 0.81852, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.8522 - accuracy: 0.8780 - precision: 0.9241 - recall: 0.8029 - val_loss: 1.0535 - val_accuracy: 0.8185 - val_precision: 0.8662 - val_recall: 0.7630 - lr: 1.2500e-05
# Epoch 23/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8240 - accuracy: 0.8919 - precision: 0.9376 - recall: 0.8217
# Epoch 23: val_accuracy did not improve from 0.81852
# 406/406 [==============================] - 98s 241ms/step - loss: 0.8240 - accuracy: 0.8919 - precision: 0.9376 - recall: 0.8217 - val_loss: 1.0919 - val_accuracy: 0.8043 - val_precision: 0.8526 - val_recall: 0.7444 - lr: 1.2500e-05
# Epoch 24/150
# 406/406 [==============================] - ETA: 0s - loss: 0.8080 - accuracy: 0.8989 - precision: 0.9420 - recall: 0.8371
# Epoch 24: val_accuracy improved from 0.81852 to 0.82284, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.8080 - accuracy: 0.8989 - precision: 0.9420 - recall: 0.8371 - val_loss: 1.0552 - val_accuracy: 0.8228 - val_precision: 0.8731 - val_recall: 0.7627 - lr: 1.2500e-05
# Epoch 25/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7857 - accuracy: 0.9193 - precision: 0.9530 - recall: 0.8642
# Epoch 25: val_accuracy improved from 0.82284 to 0.84259, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7857 - accuracy: 0.9193 - precision: 0.9530 - recall: 0.8642 - val_loss: 0.9996 - val_accuracy: 0.8426 - val_precision: 0.8812 - val_recall: 0.7944 - lr: 1.2500e-05
# Epoch 26/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7725 - accuracy: 0.9273 - precision: 0.9576 - recall: 0.8732
# Epoch 26: val_accuracy improved from 0.84259 to 0.84568, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7725 - accuracy: 0.9273 - precision: 0.9576 - recall: 0.8732 - val_loss: 0.9841 - val_accuracy: 0.8457 - val_precision: 0.8940 - val_recall: 0.8040 - lr: 1.2500e-05
# Epoch 27/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.9278 - precision: 0.9575 - recall: 0.8783
# Epoch 27: val_accuracy did not improve from 0.84568
# 406/406 [==============================] - 97s 240ms/step - loss: 0.7674 - accuracy: 0.9278 - precision: 0.9575 - recall: 0.8783 - val_loss: 1.0906 - val_accuracy: 0.8000 - val_precision: 0.8557 - val_recall: 0.7377 - lr: 1.2500e-05
# Epoch 28/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7652 - accuracy: 0.9319 - precision: 0.9599 - recall: 0.8856
# Epoch 28: val_accuracy did not improve from 0.84568
# 406/406 [==============================] - 98s 240ms/step - loss: 0.7652 - accuracy: 0.9319 - precision: 0.9599 - recall: 0.8856 - val_loss: 1.0805 - val_accuracy: 0.8083 - val_precision: 0.8535 - val_recall: 0.7623 - lr: 1.2500e-05
# Epoch 29/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7635 - accuracy: 0.9348 - precision: 0.9610 - recall: 0.8895
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 29: val_accuracy did not improve from 0.84568
# 406/406 [==============================] - 98s 240ms/step - loss: 0.7635 - accuracy: 0.9348 - precision: 0.9610 - recall: 0.8895 - val_loss: 1.0352 - val_accuracy: 0.8284 - val_precision: 0.8692 - val_recall: 0.7812 - lr: 1.2500e-05
# Epoch 30/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7431 - accuracy: 0.9498 - precision: 0.9730 - recall: 0.9072
# Epoch 30: val_accuracy improved from 0.84568 to 0.88056, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7431 - accuracy: 0.9498 - precision: 0.9730 - recall: 0.9072 - val_loss: 0.9185 - val_accuracy: 0.8806 - val_precision: 0.9079 - val_recall: 0.8454 - lr: 6.2500e-06
# Epoch 31/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.9529 - precision: 0.9725 - recall: 0.9118
# Epoch 31: val_accuracy did not improve from 0.88056
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7333 - accuracy: 0.9529 - precision: 0.9725 - recall: 0.9118 - val_loss: 0.9149 - val_accuracy: 0.8806 - val_precision: 0.9119 - val_recall: 0.8429 - lr: 6.2500e-06
# Epoch 32/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7290 - accuracy: 0.9566 - precision: 0.9755 - recall: 0.9205
# Epoch 32: val_accuracy did not improve from 0.88056
# 406/406 [==============================] - 98s 241ms/step - loss: 0.7290 - accuracy: 0.9566 - precision: 0.9755 - recall: 0.9205 - val_loss: 0.9188 - val_accuracy: 0.8731 - val_precision: 0.9069 - val_recall: 0.8330 - lr: 6.2500e-06
# Epoch 33/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7239 - accuracy: 0.9600 - precision: 0.9779 - recall: 0.9220
# Epoch 33: val_accuracy improved from 0.88056 to 0.88210, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7239 - accuracy: 0.9600 - precision: 0.9779 - recall: 0.9220 - val_loss: 0.9122 - val_accuracy: 0.8821 - val_precision: 0.9080 - val_recall: 0.8531 - lr: 6.2500e-06
# Epoch 34/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7157 - accuracy: 0.9637 - precision: 0.9810 - recall: 0.9320
# Epoch 34: val_accuracy did not improve from 0.88210
# 406/406 [==============================] - 98s 241ms/step - loss: 0.7157 - accuracy: 0.9637 - precision: 0.9810 - recall: 0.9320 - val_loss: 0.9043 - val_accuracy: 0.8821 - val_precision: 0.9173 - val_recall: 0.8491 - lr: 6.2500e-06
# Epoch 35/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.9630 - precision: 0.9792 - recall: 0.9330
# Epoch 35: val_accuracy did not improve from 0.88210
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7169 - accuracy: 0.9630 - precision: 0.9792 - recall: 0.9330 - val_loss: 0.9156 - val_accuracy: 0.8793 - val_precision: 0.9138 - val_recall: 0.8441 - lr: 6.2500e-06
# Epoch 36/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7122 - accuracy: 0.9664 - precision: 0.9828 - recall: 0.9335
# Epoch 36: val_accuracy improved from 0.88210 to 0.88457, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.7122 - accuracy: 0.9664 - precision: 0.9828 - recall: 0.9335 - val_loss: 0.9135 - val_accuracy: 0.8846 - val_precision: 0.9093 - val_recall: 0.8509 - lr: 6.2500e-06
# Epoch 37/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7069 - accuracy: 0.9647 - precision: 0.9807 - recall: 0.9345
# Epoch 37: val_accuracy did not improve from 0.88457
# 406/406 [==============================] - 98s 240ms/step - loss: 0.7069 - accuracy: 0.9647 - precision: 0.9807 - recall: 0.9345 - val_loss: 0.9034 - val_accuracy: 0.8836 - val_precision: 0.9133 - val_recall: 0.8546 - lr: 6.2500e-06
# Epoch 38/150
# 406/406 [==============================] - ETA: 0s - loss: 0.7068 - accuracy: 0.9692 - precision: 0.9838 - recall: 0.9352
# Epoch 38: val_accuracy improved from 0.88457 to 0.88735, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 241ms/step - loss: 0.7068 - accuracy: 0.9692 - precision: 0.9838 - recall: 0.9352 - val_loss: 0.8909 - val_accuracy: 0.8873 - val_precision: 0.9172 - val_recall: 0.8583 - lr: 6.2500e-06
# Epoch 39/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6991 - accuracy: 0.9708 - precision: 0.9843 - recall: 0.9422
# Epoch 39: val_accuracy did not improve from 0.88735
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6991 - accuracy: 0.9708 - precision: 0.9843 - recall: 0.9422 - val_loss: 0.8970 - val_accuracy: 0.8861 - val_precision: 0.9058 - val_recall: 0.8611 - lr: 6.2500e-06
# Epoch 40/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.9706 - precision: 0.9847 - recall: 0.9422
# Epoch 40: val_accuracy improved from 0.88735 to 0.89105, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 99s 243ms/step - loss: 0.6975 - accuracy: 0.9706 - precision: 0.9847 - recall: 0.9422 - val_loss: 0.8811 - val_accuracy: 0.8910 - val_precision: 0.9124 - val_recall: 0.8648 - lr: 6.2500e-06
# Epoch 41/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6979 - accuracy: 0.9677 - precision: 0.9833 - recall: 0.9417
# Epoch 41: val_accuracy did not improve from 0.89105
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6979 - accuracy: 0.9677 - precision: 0.9833 - recall: 0.9417 - val_loss: 0.9135 - val_accuracy: 0.8738 - val_precision: 0.8994 - val_recall: 0.8500 - lr: 6.2500e-06
# Epoch 42/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.9715 - precision: 0.9846 - recall: 0.9469
# Epoch 42: val_accuracy improved from 0.89105 to 0.89815, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.6892 - accuracy: 0.9715 - precision: 0.9846 - recall: 0.9469 - val_loss: 0.8721 - val_accuracy: 0.8981 - val_precision: 0.9148 - val_recall: 0.8778 - lr: 6.2500e-06
# Epoch 43/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.9719 - precision: 0.9849 - recall: 0.9463
# Epoch 43: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6905 - accuracy: 0.9719 - precision: 0.9849 - recall: 0.9463 - val_loss: 0.8849 - val_accuracy: 0.8846 - val_precision: 0.9145 - val_recall: 0.8586 - lr: 6.2500e-06
# Epoch 44/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6838 - accuracy: 0.9727 - precision: 0.9863 - recall: 0.9509
# Epoch 44: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6838 - accuracy: 0.9727 - precision: 0.9863 - recall: 0.9509 - val_loss: 0.9365 - val_accuracy: 0.8707 - val_precision: 0.8981 - val_recall: 0.8457 - lr: 6.2500e-06
# Epoch 45/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6826 - accuracy: 0.9761 - precision: 0.9863 - recall: 0.9509
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 45: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 98s 240ms/step - loss: 0.6826 - accuracy: 0.9761 - precision: 0.9863 - recall: 0.9509 - val_loss: 0.8843 - val_accuracy: 0.8883 - val_precision: 0.9111 - val_recall: 0.8605 - lr: 6.2500e-06
# Epoch 46/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.9786 - precision: 0.9877 - recall: 0.9558
# Epoch 46: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 98s 240ms/step - loss: 0.6812 - accuracy: 0.9786 - precision: 0.9877 - recall: 0.9558 - val_loss: 0.8574 - val_accuracy: 0.8926 - val_precision: 0.9174 - val_recall: 0.8707 - lr: 3.1250e-06
# Epoch 47/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6773 - accuracy: 0.9768 - precision: 0.9879 - recall: 0.9533
# Epoch 47: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 97s 239ms/step - loss: 0.6773 - accuracy: 0.9768 - precision: 0.9879 - recall: 0.9533 - val_loss: 0.8551 - val_accuracy: 0.8963 - val_precision: 0.9176 - val_recall: 0.8731 - lr: 3.1250e-06
# Epoch 48/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.9811 - precision: 0.9901 - recall: 0.9588
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 48: val_accuracy did not improve from 0.89815
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6717 - accuracy: 0.9811 - precision: 0.9901 - recall: 0.9588 - val_loss: 0.8469 - val_accuracy: 0.8957 - val_precision: 0.9195 - val_recall: 0.8738 - lr: 3.1250e-06
# Epoch 49/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.9827 - precision: 0.9922 - recall: 0.9613
# Epoch 49: val_accuracy improved from 0.89815 to 0.89938, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.6733 - accuracy: 0.9827 - precision: 0.9922 - recall: 0.9613 - val_loss: 0.8459 - val_accuracy: 0.8994 - val_precision: 0.9219 - val_recall: 0.8775 - lr: 1.5625e-06
# Epoch 50/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.9833 - precision: 0.9911 - recall: 0.9631
# Epoch 50: val_accuracy improved from 0.89938 to 0.90432, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.6689 - accuracy: 0.9833 - precision: 0.9911 - recall: 0.9631 - val_loss: 0.8374 - val_accuracy: 0.9043 - val_precision: 0.9225 - val_recall: 0.8812 - lr: 1.5625e-06
# Epoch 51/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6700 - accuracy: 0.9803 - precision: 0.9895 - recall: 0.9618
# Epoch 51: val_accuracy improved from 0.90432 to 0.90648, saving model to saved_model\task2_resnet50_model.h5
# 406/406 [==============================] - 98s 242ms/step - loss: 0.6700 - accuracy: 0.9803 - precision: 0.9895 - recall: 0.9618 - val_loss: 0.8363 - val_accuracy: 0.9065 - val_precision: 0.9260 - val_recall: 0.8840 - lr: 1.5625e-06
# Epoch 52/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.9806 - precision: 0.9908 - recall: 0.9606
# Epoch 52: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 98s 241ms/step - loss: 0.6720 - accuracy: 0.9806 - precision: 0.9908 - recall: 0.9606 - val_loss: 0.8400 - val_accuracy: 0.9015 - val_precision: 0.9222 - val_recall: 0.8815 - lr: 1.5625e-06
# Epoch 53/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.9842 - precision: 0.9914 - recall: 0.9638
# Epoch 53: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 98s 240ms/step - loss: 0.6680 - accuracy: 0.9842 - precision: 0.9914 - recall: 0.9638 - val_loss: 0.8428 - val_accuracy: 0.9012 - val_precision: 0.9226 - val_recall: 0.8796 - lr: 1.5625e-06
# Epoch 54/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.9807 - precision: 0.9903 - recall: 0.9599
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 54: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6695 - accuracy: 0.9807 - precision: 0.9903 - recall: 0.9599 - val_loss: 0.8451 - val_accuracy: 0.8994 - val_precision: 0.9207 - val_recall: 0.8778 - lr: 1.5625e-06
# Epoch 55/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.9839 - precision: 0.9926 - recall: 0.9665
# Epoch 55: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 98s 241ms/step - loss: 0.6659 - accuracy: 0.9839 - precision: 0.9926 - recall: 0.9665 - val_loss: 0.8360 - val_accuracy: 0.9056 - val_precision: 0.9233 - val_recall: 0.8836 - lr: 1.0000e-06
# Epoch 56/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.9848 - precision: 0.9916 - recall: 0.9658
# Epoch 56: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6643 - accuracy: 0.9848 - precision: 0.9916 - recall: 0.9658 - val_loss: 0.8420 - val_accuracy: 0.9009 - val_precision: 0.9188 - val_recall: 0.8799 - lr: 1.0000e-06
# Epoch 57/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6661 - accuracy: 0.9846 - precision: 0.9927 - recall: 0.9660
# Epoch 57: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 97s 239ms/step - loss: 0.6661 - accuracy: 0.9846 - precision: 0.9927 - recall: 0.9660 - val_loss: 0.8378 - val_accuracy: 0.9049 - val_precision: 0.9243 - val_recall: 0.8855 - lr: 1.0000e-06
# Epoch 58/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6640 - accuracy: 0.9848 - precision: 0.9923 - recall: 0.9670
# Epoch 58: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6640 - accuracy: 0.9848 - precision: 0.9923 - recall: 0.9670 - val_loss: 0.8356 - val_accuracy: 0.9006 - val_precision: 0.9229 - val_recall: 0.8793 - lr: 1.0000e-06
# Epoch 59/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.9845 - precision: 0.9926 - recall: 0.9661
# Epoch 59: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 97s 240ms/step - loss: 0.6629 - accuracy: 0.9845 - precision: 0.9926 - recall: 0.9661 - val_loss: 0.8355 - val_accuracy: 0.9000 - val_precision: 0.9221 - val_recall: 0.8799 - lr: 1.0000e-06
# Epoch 60/150
# 406/406 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.9821 - precision: 0.9898 - recall: 0.9633
# Epoch 60: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 98s 240ms/step - loss: 0.6643 - accuracy: 0.9821 - precision: 0.9898 - recall: 0.9633 - val_loss: 0.8332 - val_accuracy: 0.9031 - val_precision: 0.9211 - val_recall: 0.8861 - lr: 1.0000e-06
# Epoch 61/150
# Restoring model weights from the end of the best epoch: 51.0.6635 - accuracy: 0.9854 - precision: 0.9931 - recall: 0.9668
#
# Epoch 61: val_accuracy did not improve from 0.90648
# 406/406 [==============================] - 98s 241ms/step - loss: 0.6635 - accuracy: 0.9854 - precision: 0.9931 - recall: 0.9668 - val_loss: 0.8361 - val_accuracy: 0.9006 - val_precision: 0.9200 - val_recall: 0.8799 - lr: 1.0000e-06
# Epoch 61: early stopping

# %%
resnet_val_acc = evaluate_model(resnet50_history)

# %% [markdown]
# Check best model

# %%
histories = {
    "CNN": cnn_history,
    "EfficientNet": efficient_net_history,
    "ResNet50": resnet50_history,
}

def find_best_model(histories, task_type='classification'):
    """
    histories: dict with model names as keys and History objects as values
    task_type: 'classification' or 'regression'
    """
    best_score = -float('inf') if task_type == 'classification' else float('inf')
    best_model = None

    for name, hist in histories.items():
        if task_type == 'classification':
            val_acc = max(hist.history.get('val_accuracy', [0]))  # Updated to match compile()
            print(f"{name}: Best Val Accuracy = {val_acc:.4f}")
            if val_acc > best_score:
                best_score = val_acc
                best_model = name
        elif task_type == 'regression':
            val_mae = min(hist.history.get('val_mae', [float('inf')]))
            print(f"{name}: Best Val MAE = {val_mae:.4f}")
            if val_mae < best_score:
                best_score = val_mae
                best_model = name

    print(f"\nBest model: {best_model} with {'accuracy' if task_type == 'classification' else 'MAE'} = {best_score:.4f}")
    return best_model

find_best_model(histories, 'classification')
# Out:
# CNN: Best Val Accuracy = 0.7201
# EfficientNet: Best Val Accuracy = 0.7651
# ResNet50: Best Val Accuracy = 0.9065
#
# Best model: ResNet50 with accuracy = 0.9065
# 'ResNet50'

# %%
def evaluate_models(histories, metrics_to_check=None):
    """
    A comprehensive function to evaluate and compare multiple models based on their training histories.
    
    Parameters:
        histories: Dictionary with model names as keys and History objects as values
        metrics_to_check: List of metrics to analyze (if None, will check all available metrics)
        
    Returns:
        Dictionary with best models for different metrics
    """
    # If no specific metrics provided, collect all available metrics from histories
    if metrics_to_check is None:
        metrics_to_check = set()
        for hist in histories.values():
            for metric in hist.history.keys():
                if metric.startswith('val_'):
                    metrics_to_check.add(metric)
    
    results = {}
    summary = {}
    
    print("=" * 80)
    print(f"{'Model':<15} | {'Metric':<25} | {'Best Value':<15} | {'Epoch':<10}")
    print("=" * 80)
    
    # Process each model's history
    for model_name, history in histories.items():
        model_results = {}
        
        for metric in metrics_to_check:
            if metric in history.history:
                values = history.history[metric]
                
                is_maximize = not any(key in metric for key in ['loss', 'error', 'mae', 'mse'])
                
                if is_maximize:
                    best_value = max(values)
                    best_epoch = values.index(best_value) + 1
                else:
                    best_value = min(values)
                    best_epoch = values.index(best_value) + 1
                
                model_results[metric] = {
                    'best_value': best_value,
                    'best_epoch': best_epoch,
                    'is_maximize': is_maximize
                }
                
                value_format = f"{best_value:.4f}"
                print(f"{model_name:<15} | {metric:<25} | {value_format:<15} | {best_epoch:<10}")
                
                if metric not in summary:
                    summary[metric] = {
                        'best_model': model_name,
                        'best_value': best_value
                    }
                else:
                    current_best = summary[metric]['best_value']
                    if (is_maximize and best_value > current_best) or (not is_maximize and best_value < current_best):
                        summary[metric]['best_model'] = model_name
                        summary[metric]['best_value'] = best_value
        
        results[model_name] = model_results
    
    print("\n" + "=" * 50)
    print("BEST MODEL FOR EACH METRIC:")
    print("=" * 50)
    
    for metric, data in summary.items():
        print(f"{metric:<25}: {data['best_model']} (Value: {data['best_value']:.4f})")
    
    # Visualization of training curves
    plt.figure(figsize=(15, 10))
    
    viz_metrics = [m for m in metrics_to_check if m.startswith('val_')]
    if not viz_metrics:
        viz_metrics = list(metrics_to_check)[:4]  # fallback
    
    for i, metric in enumerate(viz_metrics[:4]):  # Max 4 plots
        plt.subplot(2, 2, i + 1)
        
        for model_name, history in histories.items():
            if metric in history.history:
                plt.plot(history.history[metric], label=f"{model_name}")
                
                train_metric = metric.replace('val_', '')
                if train_metric in history.history:
                    plt.plot(history.history[train_metric], linestyle='--',
                             alpha=0.7, label=f"{model_name} (train)")
        
        plt.title(metric.replace("val_", "Validation ").capitalize())
        plt.xlabel('Epoch')
        plt.ylabel('Value')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    return summary

best_models = evaluate_models(histories)
# Out:
# ================================================================================
# Model           | Metric                    | Best Value      | Epoch
# ================================================================================
# CNN             | val_precision             | 0.7622          | 22
# CNN             | val_loss                  | 1.4019          | 37
# CNN             | val_recall                | 0.6775          | 27
# CNN             | val_accuracy              | 0.7201          | 27
# EfficientNet    | val_precision             | 0.7999          | 41
# EfficientNet    | val_loss                  | 1.1606          | 41
# EfficientNet    | val_recall                | 0.7173          | 48
# EfficientNet    | val_accuracy              | 0.7651          | 50
# ResNet50        | val_precision             | 0.9260          | 51
# ResNet50        | val_loss                  | 0.8332          | 60
# ResNet50        | val_recall                | 0.8861          | 60
# ResNet50        | val_accuracy              | 0.9065          | 51
#
# ==================================================
# BEST MODEL FOR EACH METRIC:
# ==================================================
# val_precision            : ResNet50 (Value: 0.9260)
# val_loss                 : ResNet50 (Value: 0.8332)
# val_recall               : ResNet50 (Value: 0.8861)
# val_accuracy             : ResNet50 (Value: 0.9065)
